# %%
from __future__ import print_function, division

import torch
import torch.optim as optim

from torch.optim import lr_scheduler
from torchvision import datasets, transforms
import time
import os

import torch.nn as nn

# TODO: You can modify the network architecture
class Net(nn.Module):
    """
    Input - 1x32x32
    Output - 10
    """
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=7, padding=3, stride=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(p=0.3),

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(p=0.3),

            nn.Flatten(), 
            nn.Linear(256*4*4, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
            )
        
    def forward(self, xb):
        return self.network(xb)

# %%
from random import randrange
# TODO: You can try different augmentation strategies
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomAffine(degrees=10, translate=(0,0.1)),
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),

    ]),
    'test': transforms.Compose([
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

# %%
data_dir = '/kaggle/input/dtc314/data' # Suppose the dataset is stored under this folder
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'test']} # Read train and test sets, respectively.

train_dataloader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=128,
                                             shuffle=True, num_workers=4)

test_dataloader = torch.utils.data.DataLoader(image_datasets['test'], batch_size=128,
                                             shuffle=False, num_workers=4)

train_size =len(image_datasets['train'])


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # Set device to "cpu" if you have no gpu

# %%
history = dict()

def train_test(model, criterion, optimizer, scheduler, num_epochs=25):
    train_loss = []
    train_accuracy = []
    val_loss = [] 
    val_accuracy = []
    model.train()
    for epoch in range(num_epochs):
        running_training_loss = 0.0
        running_training_accuracy = 0.0
        iteration_training_loss = 0.0
        total_training_predictions = 0
       
        start_time = time.time()
        for i, data in enumerate(train_dataloader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_training_loss += loss.item()*inputs.size(0)
            
            _, predicted = torch.max(outputs.data, 1)
            total_training_predictions += labels.size(0)
            running_training_accuracy += (predicted == labels).sum().item()
            iteration_training_loss += loss.item() 
            if (i+1) % 100 == 0:
                print('Epoch:[%d]-Iteration:[%d], training loss: %.3f' %
                      (epoch + 1,i+1,iteration_training_loss/(i+1)))
        end_time = time.time()
        print('Time cost of one epoch: [%d]s' % (end_time-start_time))
        
        epoch_training_accuracy = running_training_accuracy / train_size*100
        epoch_training_loss = running_training_loss / train_size
        
        print('Epoch:[%d], training accuracy: %.1f, training loss: %.3f' %
              (epoch + 1,epoch_training_accuracy, epoch_training_loss))
        
        train_loss.append(epoch_training_loss)
        train_accuracy.append(epoch_training_accuracy)
        
        correct = 0
        total = 0
        labelsCorrect = [0 for i in range(10)]
        labelsTotal = [0 for i in range(10)]
        model.eval()
        # Since we're not training, we don't need to calculate the gradients for our outputs
        with torch.no_grad():
            for data in test_dataloader:
                images, labels = data[0].to(device), data[1].to(device)
                # calculate outputs by running images through the network
                outputs = model(images)
                # the class with the highest energy is what we choose as prediction
                _, predicted = torch.max(outputs.data, 1)
                tmp = (predicted == labels)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                for i in range(labels.size(0)): 
                    label = labels.data[i]
                    labelsCorrect[label] += tmp[i]
                    labelsTotal[label] += 1
        accuracy = float(100) * correct / total
        print(f'Accuracy of the network on test images: {accuracy}')
        for i in range(10): 
            acc = (labelsCorrect[i]/labelsTotal[i]).item
            print(f"Test Accuracy of {i}: {round((labelsCorrect[i]/labelsTotal[i]).item()*100,2)}")        
        val_accuracy.append(accuracy)
        scheduler.step()
        
    print('Finished Training')

    history['train_loss'] = train_loss
    history['train_accuracy'] = train_accuracy
    history['val_accuracy'] = val_accuracy

    return history, accuracy

# %%
epoch = 50

if __name__ == '__main__':
    end = time.time()
    model_ft = Net().to(device) # Model initialization
    print(model_ft.network)
    criterion = nn.CrossEntropyLoss() # Loss function initialization

    # TODO: Adjust the following hyper-parameters: initial learning rate, decay strategy of the learning rate, 
    #       number of training epochs
    optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.001) # The initial learning rate is 1e-3

    exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=20, gamma=0.7) 
    
    history, accuracy = train_test(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
               num_epochs=epoch)
    
    print("time required %.2fs" %(time.time() - end))
# Out:
# Sequential(
#   (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (1): ReLU()
#   (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU()
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Dropout(p=0.3, inplace=False)
#   (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU()
#   (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU()
#   (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (11): Dropout(p=0.3, inplace=False)
#   (12): Flatten(start_dim=1, end_dim=-1)
#   (13): Linear(in_features=4096, out_features=128, bias=True)
#   (14): ReLU()
#   (15): Linear(in_features=128, out_features=10, bias=True)
# )
# Epoch:[1]-Iteration:[100], training loss: 2.302
# Epoch:[1]-Iteration:[200], training loss: 1.972
# Time cost of one epoch: [78]s
# Epoch:[1], training accuracy: 31.2, training loss: 1.856
# Accuracy of the network on test images: 70.92
# Test Accuracy of 0: 76.2
# Test Accuracy of 1: 74.0
# Test Accuracy of 2: 78.2
# Test Accuracy of 3: 27.0
# Test Accuracy of 4: 73.6
# Test Accuracy of 5: 82.6
# Test Accuracy of 6: 67.2
# Test Accuracy of 7: 80.0
# Test Accuracy of 8: 66.4
# Test Accuracy of 9: 84.0
# Epoch:[2]-Iteration:[100], training loss: 0.856
# Epoch:[2]-Iteration:[200], training loss: 0.751
# Time cost of one epoch: [70]s
# Epoch:[2], training accuracy: 77.1, training loss: 0.724
# Accuracy of the network on test images: 85.64
# Test Accuracy of 0: 87.0
# Test Accuracy of 1: 90.0
# Test Accuracy of 2: 89.8
# Test Accuracy of 3: 87.4
# Test Accuracy of 4: 89.0
# Test Accuracy of 5: 78.6
# Test Accuracy of 6: 79.4
# Test Accuracy of 7: 90.8
# Test Accuracy of 8: 79.2
# Test Accuracy of 9: 85.2
# Epoch:[3]-Iteration:[100], training loss: 0.509
# Epoch:[3]-Iteration:[200], training loss: 0.489
# Time cost of one epoch: [70]s
# Epoch:[3], training accuracy: 85.5, training loss: 0.482
# Accuracy of the network on test images: 89.0
# Test Accuracy of 0: 88.0
# Test Accuracy of 1: 92.8
# Test Accuracy of 2: 90.2
# Test Accuracy of 3: 86.0
# Test Accuracy of 4: 95.6
# Test Accuracy of 5: 85.4
# Test Accuracy of 6: 88.0
# Test Accuracy of 7: 91.6
# Test Accuracy of 8: 84.6
# Test Accuracy of 9: 87.8
# Epoch:[4]-Iteration:[100], training loss: 0.399
# Epoch:[4]-Iteration:[200], training loss: 0.398
# Time cost of one epoch: [71]s
# Epoch:[4], training accuracy: 87.9, training loss: 0.395
# Accuracy of the network on test images: 89.32
# Test Accuracy of 0: 94.6
# Test Accuracy of 1: 86.2
# Test Accuracy of 2: 92.8
# Test Accuracy of 3: 87.4
# Test Accuracy of 4: 90.6
# Test Accuracy of 5: 84.4
# Test Accuracy of 6: 85.0
# Test Accuracy of 7: 94.2
# Test Accuracy of 8: 90.8
# Test Accuracy of 9: 87.2
# Epoch:[5]-Iteration:[100], training loss: 0.342
# Epoch:[5]-Iteration:[200], training loss: 0.342
# Time cost of one epoch: [71]s
# Epoch:[5], training accuracy: 89.6, training loss: 0.344
# Accuracy of the network on test images: 91.1
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 90.2
# Test Accuracy of 2: 91.4
# Test Accuracy of 3: 87.4
# Test Accuracy of 4: 93.6
# Test Accuracy of 5: 90.8
# Test Accuracy of 6: 89.0
# Test Accuracy of 7: 93.4
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 90.0
# Epoch:[6]-Iteration:[100], training loss: 0.316
# Epoch:[6]-Iteration:[200], training loss: 0.312
# Time cost of one epoch: [71]s
# Epoch:[6], training accuracy: 90.6, training loss: 0.311
# Accuracy of the network on test images: 91.16
# Test Accuracy of 0: 92.0
# Test Accuracy of 1: 88.0
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 89.0
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 88.8
# Test Accuracy of 6: 91.8
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 87.2
# Test Accuracy of 9: 91.8
# Epoch:[7]-Iteration:[100], training loss: 0.274
# Epoch:[7]-Iteration:[200], training loss: 0.291
# Time cost of one epoch: [71]s
# Epoch:[7], training accuracy: 91.1, training loss: 0.292
# Accuracy of the network on test images: 90.9
# Test Accuracy of 0: 91.6
# Test Accuracy of 1: 92.8
# Test Accuracy of 2: 95.2
# Test Accuracy of 3: 88.0
# Test Accuracy of 4: 95.0
# Test Accuracy of 5: 89.6
# Test Accuracy of 6: 84.6
# Test Accuracy of 7: 90.4
# Test Accuracy of 8: 90.4
# Test Accuracy of 9: 91.4
# Epoch:[8]-Iteration:[100], training loss: 0.264
# Epoch:[8]-Iteration:[200], training loss: 0.269
# Time cost of one epoch: [71]s
# Epoch:[8], training accuracy: 91.8, training loss: 0.269
# Accuracy of the network on test images: 91.22
# Test Accuracy of 0: 88.8
# Test Accuracy of 1: 93.0
# Test Accuracy of 2: 90.4
# Test Accuracy of 3: 89.0
# Test Accuracy of 4: 96.8
# Test Accuracy of 5: 87.8
# Test Accuracy of 6: 92.6
# Test Accuracy of 7: 92.4
# Test Accuracy of 8: 90.0
# Test Accuracy of 9: 91.4
# Epoch:[9]-Iteration:[100], training loss: 0.237
# Epoch:[9]-Iteration:[200], training loss: 0.250
# Time cost of one epoch: [72]s
# Epoch:[9], training accuracy: 92.6, training loss: 0.249
# Accuracy of the network on test images: 91.76
# Test Accuracy of 0: 92.0
# Test Accuracy of 1: 89.0
# Test Accuracy of 2: 93.2
# Test Accuracy of 3: 91.4
# Test Accuracy of 4: 92.8
# Test Accuracy of 5: 88.8
# Test Accuracy of 6: 91.0
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 92.6
# Epoch:[10]-Iteration:[100], training loss: 0.221
# Epoch:[10]-Iteration:[200], training loss: 0.225
# Time cost of one epoch: [71]s
# Epoch:[10], training accuracy: 93.2, training loss: 0.228
# Accuracy of the network on test images: 92.18
# Test Accuracy of 0: 94.2
# Test Accuracy of 1: 92.4
# Test Accuracy of 2: 92.2
# Test Accuracy of 3: 89.0
# Test Accuracy of 4: 94.0
# Test Accuracy of 5: 91.2
# Test Accuracy of 6: 89.8
# Test Accuracy of 7: 93.2
# Test Accuracy of 8: 93.8
# Test Accuracy of 9: 92.0
# Epoch:[11]-Iteration:[100], training loss: 0.221
# Epoch:[11]-Iteration:[200], training loss: 0.219
# Time cost of one epoch: [71]s
# Epoch:[11], training accuracy: 93.3, training loss: 0.221
# Accuracy of the network on test images: 91.58
# Test Accuracy of 0: 88.0
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 94.6
# Test Accuracy of 3: 90.6
# Test Accuracy of 4: 90.0
# Test Accuracy of 5: 89.6
# Test Accuracy of 6: 94.2
# Test Accuracy of 7: 94.6
# Test Accuracy of 8: 88.6
# Test Accuracy of 9: 93.6
# Epoch:[12]-Iteration:[100], training loss: 0.189
# Epoch:[12]-Iteration:[200], training loss: 0.201
# Time cost of one epoch: [71]s
# Epoch:[12], training accuracy: 93.8, training loss: 0.204
# Accuracy of the network on test images: 92.0
# Test Accuracy of 0: 94.8
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 94.2
# Test Accuracy of 3: 89.0
# Test Accuracy of 4: 91.6
# Test Accuracy of 5: 91.8
# Test Accuracy of 6: 92.8
# Test Accuracy of 7: 92.8
# Test Accuracy of 8: 88.8
# Test Accuracy of 9: 90.8
# Epoch:[13]-Iteration:[100], training loss: 0.194
# Epoch:[13]-Iteration:[200], training loss: 0.193
# Time cost of one epoch: [71]s
# Epoch:[13], training accuracy: 94.1, training loss: 0.192
# Accuracy of the network on test images: 91.94
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 90.0
# Test Accuracy of 2: 91.4
# Test Accuracy of 3: 89.8
# Test Accuracy of 4: 94.0
# Test Accuracy of 5: 91.2
# Test Accuracy of 6: 90.4
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 90.2
# Test Accuracy of 9: 93.2
# Epoch:[14]-Iteration:[100], training loss: 0.180
# Epoch:[14]-Iteration:[200], training loss: 0.183
# Time cost of one epoch: [72]s
# Epoch:[14], training accuracy: 94.2, training loss: 0.185
# Accuracy of the network on test images: 91.7
# Test Accuracy of 0: 90.8
# Test Accuracy of 1: 89.2
# Test Accuracy of 2: 92.0
# Test Accuracy of 3: 89.2
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 89.6
# Test Accuracy of 6: 90.8
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 91.2
# Test Accuracy of 9: 93.8
# Epoch:[15]-Iteration:[100], training loss: 0.164
# Epoch:[15]-Iteration:[200], training loss: 0.165
# Time cost of one epoch: [71]s
# Epoch:[15], training accuracy: 94.7, training loss: 0.169
# Accuracy of the network on test images: 91.94
# Test Accuracy of 0: 91.6
# Test Accuracy of 1: 89.8
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.2
# Test Accuracy of 4: 91.6
# Test Accuracy of 5: 92.6
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 89.2
# Test Accuracy of 9: 92.8
# Epoch:[16]-Iteration:[100], training loss: 0.150
# Epoch:[16]-Iteration:[200], training loss: 0.156
# Time cost of one epoch: [71]s
# Epoch:[16], training accuracy: 95.1, training loss: 0.157
# Accuracy of the network on test images: 91.58
# Test Accuracy of 0: 92.2
# Test Accuracy of 1: 90.4
# Test Accuracy of 2: 94.4
# Test Accuracy of 3: 87.8
# Test Accuracy of 4: 92.6
# Test Accuracy of 5: 92.6
# Test Accuracy of 6: 92.4
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 86.8
# Test Accuracy of 9: 91.6
# Epoch:[17]-Iteration:[100], training loss: 0.157
# Epoch:[17]-Iteration:[200], training loss: 0.156
# Time cost of one epoch: [71]s
# Epoch:[17], training accuracy: 95.2, training loss: 0.156
# Accuracy of the network on test images: 91.74
# Test Accuracy of 0: 92.8
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 92.2
# Test Accuracy of 3: 86.4
# Test Accuracy of 4: 92.8
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 92.2
# Test Accuracy of 7: 92.0
# Test Accuracy of 8: 91.4
# Test Accuracy of 9: 93.4
# Epoch:[18]-Iteration:[100], training loss: 0.150
# Epoch:[18]-Iteration:[200], training loss: 0.150
# Time cost of one epoch: [71]s
# Epoch:[18], training accuracy: 95.4, training loss: 0.150
# Accuracy of the network on test images: 92.1
# Test Accuracy of 0: 93.2
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 93.0
# Test Accuracy of 3: 87.0
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 92.0
# Test Accuracy of 6: 90.6
# Test Accuracy of 7: 93.6
# Test Accuracy of 8: 90.2
# Test Accuracy of 9: 92.6
# Epoch:[19]-Iteration:[100], training loss: 0.135
# Epoch:[19]-Iteration:[200], training loss: 0.137
# Time cost of one epoch: [71]s
# Epoch:[19], training accuracy: 95.7, training loss: 0.138
# Accuracy of the network on test images: 91.76
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 88.4
# Test Accuracy of 2: 93.0
# Test Accuracy of 3: 89.4
# Test Accuracy of 4: 93.4
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 92.0
# Test Accuracy of 7: 93.4
# Test Accuracy of 8: 92.0
# Test Accuracy of 9: 92.2
# Epoch:[20]-Iteration:[100], training loss: 0.133
# Epoch:[20]-Iteration:[200], training loss: 0.136
# Time cost of one epoch: [71]s
# Epoch:[20], training accuracy: 95.5, training loss: 0.137
# Accuracy of the network on test images: 91.32
# Test Accuracy of 0: 91.2
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 93.2
# Test Accuracy of 3: 85.4
# Test Accuracy of 4: 92.2
# Test Accuracy of 5: 90.2
# Test Accuracy of 6: 91.4
# Test Accuracy of 7: 94.0
# Test Accuracy of 8: 90.8
# Test Accuracy of 9: 91.6
# Epoch:[21]-Iteration:[100], training loss: 0.115
# Epoch:[21]-Iteration:[200], training loss: 0.111
# Time cost of one epoch: [71]s
# Epoch:[21], training accuracy: 96.6, training loss: 0.109
# Accuracy of the network on test images: 92.04
# Test Accuracy of 0: 93.0
# Test Accuracy of 1: 89.6
# Test Accuracy of 2: 94.0
# Test Accuracy of 3: 89.6
# Test Accuracy of 4: 93.6
# Test Accuracy of 5: 89.8
# Test Accuracy of 6: 90.6
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 90.6
# Test Accuracy of 9: 93.8
# Epoch:[22]-Iteration:[100], training loss: 0.100
# Epoch:[22]-Iteration:[200], training loss: 0.097
# Time cost of one epoch: [71]s
# Epoch:[22], training accuracy: 96.9, training loss: 0.099
# Accuracy of the network on test images: 91.78
# Test Accuracy of 0: 91.4
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 90.8
# Test Accuracy of 3: 89.8
# Test Accuracy of 4: 93.4
# Test Accuracy of 5: 91.8
# Test Accuracy of 6: 90.8
# Test Accuracy of 7: 94.2
# Test Accuracy of 8: 91.0
# Test Accuracy of 9: 92.6
# Epoch:[23]-Iteration:[100], training loss: 0.092
# Epoch:[23]-Iteration:[200], training loss: 0.089
# Time cost of one epoch: [71]s
# Epoch:[23], training accuracy: 97.1, training loss: 0.090
# Accuracy of the network on test images: 91.9
# Test Accuracy of 0: 92.8
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 92.2
# Test Accuracy of 3: 86.6
# Test Accuracy of 4: 91.4
# Test Accuracy of 5: 95.0
# Test Accuracy of 6: 90.0
# Test Accuracy of 7: 92.6
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 93.6
# Epoch:[24]-Iteration:[100], training loss: 0.093
# Epoch:[24]-Iteration:[200], training loss: 0.092
# Time cost of one epoch: [71]s
# Epoch:[24], training accuracy: 97.0, training loss: 0.094
# Accuracy of the network on test images: 91.8
# Test Accuracy of 0: 90.8
# Test Accuracy of 1: 90.0
# Test Accuracy of 2: 92.6
# Test Accuracy of 3: 87.0
# Test Accuracy of 4: 95.8
# Test Accuracy of 5: 91.4
# Test Accuracy of 6: 94.6
# Test Accuracy of 7: 93.4
# Test Accuracy of 8: 88.2
# Test Accuracy of 9: 94.2
# Epoch:[25]-Iteration:[100], training loss: 0.089
# Epoch:[25]-Iteration:[200], training loss: 0.086
# Time cost of one epoch: [70]s
# Epoch:[25], training accuracy: 97.2, training loss: 0.087
# Accuracy of the network on test images: 91.48
# Test Accuracy of 0: 89.6
# Test Accuracy of 1: 90.6
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 86.8
# Test Accuracy of 4: 95.0
# Test Accuracy of 5: 90.0
# Test Accuracy of 6: 90.2
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 90.2
# Test Accuracy of 9: 93.2
# Epoch:[26]-Iteration:[100], training loss: 0.077
# Epoch:[26]-Iteration:[200], training loss: 0.075
# Time cost of one epoch: [71]s
# Epoch:[26], training accuracy: 97.5, training loss: 0.079
# Accuracy of the network on test images: 91.6
# Test Accuracy of 0: 89.6
# Test Accuracy of 1: 91.4
# Test Accuracy of 2: 91.6
# Test Accuracy of 3: 89.6
# Test Accuracy of 4: 91.8
# Test Accuracy of 5: 90.8
# Test Accuracy of 6: 91.2
# Test Accuracy of 7: 92.8
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 94.6
# Epoch:[27]-Iteration:[100], training loss: 0.071
# Epoch:[27]-Iteration:[200], training loss: 0.079
# Time cost of one epoch: [71]s
# Epoch:[27], training accuracy: 97.4, training loss: 0.082
# Accuracy of the network on test images: 91.44
# Test Accuracy of 0: 88.4
# Test Accuracy of 1: 93.0
# Test Accuracy of 2: 92.0
# Test Accuracy of 3: 87.6
# Test Accuracy of 4: 93.8
# Test Accuracy of 5: 88.4
# Test Accuracy of 6: 93.2
# Test Accuracy of 7: 93.8
# Test Accuracy of 8: 89.4
# Test Accuracy of 9: 94.8
# Epoch:[28]-Iteration:[100], training loss: 0.071
# Epoch:[28]-Iteration:[200], training loss: 0.076
# Time cost of one epoch: [71]s
# Epoch:[28], training accuracy: 97.6, training loss: 0.075
# Accuracy of the network on test images: 91.6
# Test Accuracy of 0: 90.6
# Test Accuracy of 1: 90.8
# Test Accuracy of 2: 94.4
# Test Accuracy of 3: 87.4
# Test Accuracy of 4: 92.4
# Test Accuracy of 5: 90.0
# Test Accuracy of 6: 90.4
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 91.2
# Test Accuracy of 9: 94.0
# Epoch:[29]-Iteration:[100], training loss: 0.081
# Epoch:[29]-Iteration:[200], training loss: 0.076
# Time cost of one epoch: [71]s
# Epoch:[29], training accuracy: 97.6, training loss: 0.076
# Accuracy of the network on test images: 90.9
# Test Accuracy of 0: 91.4
# Test Accuracy of 1: 90.4
# Test Accuracy of 2: 89.6
# Test Accuracy of 3: 86.4
# Test Accuracy of 4: 94.4
# Test Accuracy of 5: 87.0
# Test Accuracy of 6: 92.8
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 89.6
# Test Accuracy of 9: 92.4
# Epoch:[30]-Iteration:[100], training loss: 0.069
# Epoch:[30]-Iteration:[200], training loss: 0.072
# Time cost of one epoch: [70]s
# Epoch:[30], training accuracy: 97.7, training loss: 0.073
# Accuracy of the network on test images: 91.2
# Test Accuracy of 0: 92.0
# Test Accuracy of 1: 91.8
# Test Accuracy of 2: 91.0
# Test Accuracy of 3: 84.2
# Test Accuracy of 4: 91.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 92.0
# Test Accuracy of 7: 93.4
# Test Accuracy of 8: 93.0
# Test Accuracy of 9: 90.8
# Epoch:[31]-Iteration:[100], training loss: 0.072
# Epoch:[31]-Iteration:[200], training loss: 0.073
# Time cost of one epoch: [71]s
# Epoch:[31], training accuracy: 97.5, training loss: 0.074
# Accuracy of the network on test images: 91.58
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 91.4
# Test Accuracy of 3: 86.4
# Test Accuracy of 4: 93.4
# Test Accuracy of 5: 88.8
# Test Accuracy of 6: 92.2
# Test Accuracy of 7: 94.0
# Test Accuracy of 8: 91.0
# Test Accuracy of 9: 92.0
# Epoch:[32]-Iteration:[100], training loss: 0.066
# Epoch:[32]-Iteration:[200], training loss: 0.071
# Time cost of one epoch: [71]s
# Epoch:[32], training accuracy: 97.6, training loss: 0.072
# Accuracy of the network on test images: 91.38
# Test Accuracy of 0: 90.8
# Test Accuracy of 1: 93.6
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 85.6
# Test Accuracy of 4: 92.6
# Test Accuracy of 5: 93.2
# Test Accuracy of 6: 92.4
# Test Accuracy of 7: 92.8
# Test Accuracy of 8: 87.6
# Test Accuracy of 9: 91.6
# Epoch:[33]-Iteration:[100], training loss: 0.067
# Epoch:[33]-Iteration:[200], training loss: 0.065
# Time cost of one epoch: [71]s
# Epoch:[33], training accuracy: 97.9, training loss: 0.066
# Accuracy of the network on test images: 91.6
# Test Accuracy of 0: 89.4
# Test Accuracy of 1: 92.2
# Test Accuracy of 2: 94.2
# Test Accuracy of 3: 87.4
# Test Accuracy of 4: 93.6
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 91.2
# Test Accuracy of 7: 92.2
# Test Accuracy of 8: 91.2
# Test Accuracy of 9: 94.2
# Epoch:[34]-Iteration:[100], training loss: 0.071
# Epoch:[34]-Iteration:[200], training loss: 0.066
# Time cost of one epoch: [71]s
# Epoch:[34], training accuracy: 97.8, training loss: 0.068
# Accuracy of the network on test images: 91.92
# Test Accuracy of 0: 90.8
# Test Accuracy of 1: 91.0
# Test Accuracy of 2: 91.6
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 93.4
# Test Accuracy of 5: 89.2
# Test Accuracy of 6: 92.4
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 92.0
# Test Accuracy of 9: 93.2
# Epoch:[35]-Iteration:[100], training loss: 0.058
# Epoch:[35]-Iteration:[200], training loss: 0.061
# Time cost of one epoch: [71]s
# Epoch:[35], training accuracy: 97.9, training loss: 0.062
# Accuracy of the network on test images: 91.46
# Test Accuracy of 0: 91.2
# Test Accuracy of 1: 91.8
# Test Accuracy of 2: 93.2
# Test Accuracy of 3: 87.8
# Test Accuracy of 4: 93.0
# Test Accuracy of 5: 88.4
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 94.6
# Test Accuracy of 8: 87.0
# Test Accuracy of 9: 94.0
# Epoch:[36]-Iteration:[100], training loss: 0.065
# Epoch:[36]-Iteration:[200], training loss: 0.064
# Time cost of one epoch: [71]s
# Epoch:[36], training accuracy: 97.9, training loss: 0.065
# Accuracy of the network on test images: 92.06
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 91.6
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 87.0
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 91.4
# Test Accuracy of 6: 92.8
# Test Accuracy of 7: 91.8
# Test Accuracy of 8: 90.6
# Test Accuracy of 9: 93.2
# Epoch:[37]-Iteration:[100], training loss: 0.059
# Epoch:[37]-Iteration:[200], training loss: 0.063
# Time cost of one epoch: [71]s
# Epoch:[37], training accuracy: 97.9, training loss: 0.062
# Accuracy of the network on test images: 91.66
# Test Accuracy of 0: 90.0
# Test Accuracy of 1: 92.6
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 87.0
# Test Accuracy of 4: 94.0
# Test Accuracy of 5: 92.8
# Test Accuracy of 6: 91.2
# Test Accuracy of 7: 93.2
# Test Accuracy of 8: 89.8
# Test Accuracy of 9: 92.6
# Epoch:[38]-Iteration:[100], training loss: 0.050
# Epoch:[38]-Iteration:[200], training loss: 0.053
# Time cost of one epoch: [71]s
# Epoch:[38], training accuracy: 98.2, training loss: 0.054
# Accuracy of the network on test images: 91.76
# Test Accuracy of 0: 91.6
# Test Accuracy of 1: 92.4
# Test Accuracy of 2: 92.6
# Test Accuracy of 3: 85.0
# Test Accuracy of 4: 94.0
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 91.0
# Test Accuracy of 7: 94.2
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 92.2
# Epoch:[39]-Iteration:[100], training loss: 0.057
# Epoch:[39]-Iteration:[200], training loss: 0.059
# Time cost of one epoch: [71]s
# Epoch:[39], training accuracy: 98.0, training loss: 0.060
# Accuracy of the network on test images: 91.68
# Test Accuracy of 0: 91.4
# Test Accuracy of 1: 91.4
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.4
# Test Accuracy of 4: 94.0
# Test Accuracy of 5: 89.6
# Test Accuracy of 6: 90.0
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 91.4
# Test Accuracy of 9: 92.2
# Epoch:[40]-Iteration:[100], training loss: 0.065
# Epoch:[40]-Iteration:[200], training loss: 0.064
# Time cost of one epoch: [71]s
# Epoch:[40], training accuracy: 97.9, training loss: 0.065
# Accuracy of the network on test images: 91.18
# Test Accuracy of 0: 90.2
# Test Accuracy of 1: 91.8
# Test Accuracy of 2: 91.2
# Test Accuracy of 3: 86.4
# Test Accuracy of 4: 92.8
# Test Accuracy of 5: 90.2
# Test Accuracy of 6: 95.2
# Test Accuracy of 7: 93.4
# Test Accuracy of 8: 91.4
# Test Accuracy of 9: 89.2
# Epoch:[41]-Iteration:[100], training loss: 0.047
# Epoch:[41]-Iteration:[200], training loss: 0.043
# Time cost of one epoch: [71]s
# Epoch:[41], training accuracy: 98.6, training loss: 0.043
# Accuracy of the network on test images: 92.14
# Test Accuracy of 0: 92.2
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 93.0
# Test Accuracy of 3: 87.2
# Test Accuracy of 4: 92.6
# Test Accuracy of 5: 90.0
# Test Accuracy of 6: 94.4
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 90.0
# Test Accuracy of 9: 92.4
# Epoch:[42]-Iteration:[100], training loss: 0.041
# Epoch:[42]-Iteration:[200], training loss: 0.040
# Time cost of one epoch: [71]s
# Epoch:[42], training accuracy: 98.5, training loss: 0.041
# Accuracy of the network on test images: 91.86
# Test Accuracy of 0: 94.2
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 90.0
# Test Accuracy of 3: 86.0
# Test Accuracy of 4: 93.2
# Test Accuracy of 5: 90.8
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 93.4
# Test Accuracy of 8: 92.4
# Test Accuracy of 9: 93.0
# Epoch:[43]-Iteration:[100], training loss: 0.036
# Epoch:[43]-Iteration:[200], training loss: 0.036
# Time cost of one epoch: [71]s
# Epoch:[43], training accuracy: 98.8, training loss: 0.038
# Accuracy of the network on test images: 91.64
# Test Accuracy of 0: 91.2
# Test Accuracy of 1: 91.2
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 87.4
# Test Accuracy of 4: 93.2
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 92.4
# Test Accuracy of 7: 94.6
# Test Accuracy of 8: 87.4
# Test Accuracy of 9: 93.2
# Epoch:[44]-Iteration:[100], training loss: 0.035
# Epoch:[44]-Iteration:[200], training loss: 0.034
# Time cost of one epoch: [70]s
# Epoch:[44], training accuracy: 98.8, training loss: 0.036
# Accuracy of the network on test images: 91.58
# Test Accuracy of 0: 92.8
# Test Accuracy of 1: 91.8
# Test Accuracy of 2: 90.8
# Test Accuracy of 3: 90.0
# Test Accuracy of 4: 94.2
# Test Accuracy of 5: 88.4
# Test Accuracy of 6: 91.6
# Test Accuracy of 7: 93.6
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 91.0
# Epoch:[45]-Iteration:[100], training loss: 0.033
# Epoch:[45]-Iteration:[200], training loss: 0.034
# Time cost of one epoch: [71]s
# Epoch:[45], training accuracy: 98.8, training loss: 0.035
# Accuracy of the network on test images: 92.06
# Test Accuracy of 0: 94.0
# Test Accuracy of 1: 90.8
# Test Accuracy of 2: 90.8
# Test Accuracy of 3: 88.8
# Test Accuracy of 4: 92.8
# Test Accuracy of 5: 91.6
# Test Accuracy of 6: 94.0
# Test Accuracy of 7: 96.0
# Test Accuracy of 8: 90.8
# Test Accuracy of 9: 91.0
# Epoch:[46]-Iteration:[100], training loss: 0.041
# Epoch:[46]-Iteration:[200], training loss: 0.038
# Time cost of one epoch: [71]s
# Epoch:[46], training accuracy: 98.7, training loss: 0.037
# Accuracy of the network on test images: 92.12
# Test Accuracy of 0: 92.6
# Test Accuracy of 1: 94.0
# Test Accuracy of 2: 92.4
# Test Accuracy of 3: 86.6
# Test Accuracy of 4: 94.0
# Test Accuracy of 5: 91.6
# Test Accuracy of 6: 91.4
# Test Accuracy of 7: 94.6
# Test Accuracy of 8: 93.0
# Test Accuracy of 9: 91.0
# Epoch:[47]-Iteration:[100], training loss: 0.028
# Epoch:[47]-Iteration:[200], training loss: 0.029
# Time cost of one epoch: [71]s
# Epoch:[47], training accuracy: 99.0, training loss: 0.031
# Accuracy of the network on test images: 91.66
# Test Accuracy of 0: 94.2
# Test Accuracy of 1: 89.6
# Test Accuracy of 2: 89.0
# Test Accuracy of 3: 87.6
# Test Accuracy of 4: 91.6
# Test Accuracy of 5: 87.8
# Test Accuracy of 6: 94.4
# Test Accuracy of 7: 97.0
# Test Accuracy of 8: 91.2
# Test Accuracy of 9: 94.2
# Epoch:[48]-Iteration:[100], training loss: 0.029
# Epoch:[48]-Iteration:[200], training loss: 0.030
# Time cost of one epoch: [71]s
# Epoch:[48], training accuracy: 98.9, training loss: 0.032
# Accuracy of the network on test images: 91.86
# Test Accuracy of 0: 92.8
# Test Accuracy of 1: 91.6
# Test Accuracy of 2: 92.0
# Test Accuracy of 3: 87.6
# Test Accuracy of 4: 94.2
# Test Accuracy of 5: 90.8
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 88.6
# Test Accuracy of 9: 90.8
# Epoch:[49]-Iteration:[100], training loss: 0.036
# Epoch:[49]-Iteration:[200], training loss: 0.037
# Time cost of one epoch: [71]s
# Epoch:[49], training accuracy: 98.9, training loss: 0.037
# Accuracy of the network on test images: 91.86
# Test Accuracy of 0: 93.2
# Test Accuracy of 1: 91.2
# Test Accuracy of 2: 91.0
# Test Accuracy of 3: 87.6
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 91.6
# Test Accuracy of 6: 93.2
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 89.6
# Test Accuracy of 9: 90.6
# Epoch:[50]-Iteration:[100], training loss: 0.031
# Epoch:[50]-Iteration:[200], training loss: 0.032
# Time cost of one epoch: [72]s
# Epoch:[50], training accuracy: 99.0, training loss: 0.031
# Accuracy of the network on test images: 91.88
# Test Accuracy of 0: 94.4
# Test Accuracy of 1: 91.0
# Test Accuracy of 2: 92.6
# Test Accuracy of 3: 89.4
# Test Accuracy of 4: 93.2
# Test Accuracy of 5: 91.2
# Test Accuracy of 6: 93.0
# Test Accuracy of 7: 94.4
# Test Accuracy of 8: 88.6
# Test Accuracy of 9: 91.0
# Finished Training
# time required 3832.13s

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(list(range(1,epoch+1)), history["train_accuracy"], label="Train")
plt.plot(list(range(1,epoch+1)), history["val_accuracy"], label="Test")
plt.xlabel("Epoch")
ax = plt.gca()
ax.set_ylim([90, 95])
plt.ylabel("Accuracy")
plt.legend()
plt.show()
print("Epoch with max test accuracy:", history["val_accuracy"].index(min(history["val_accuracy"]))+1)
# Out:
# Epoch with max test accuracy: 1
