# %%
from __future__ import print_function, division

import torch
import torch.optim as optim

from torch.optim import lr_scheduler
from torchvision import datasets, transforms
import time
import os

import torch.nn as nn

# TODO: You can modify the network architecture
class Net(nn.Module):
    """
    Input - 1x32x32
    Output - 10
    """
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=7, padding=3, stride=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(p=0.3),

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(p=0.3),

            nn.Flatten(), 
            nn.Linear(256*4*4, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
            )
        
    def forward(self, xb):
        return self.network(xb)

# %%
from random import randrange
# TODO: You can try different augmentation strategies
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomChoice([transforms.Pad(padding=4, fill=(randrange(256),randrange(256),randrange(256))), transforms.ElasticTransform(),transforms.GaussianBlur((3,3))]),
        transforms.RandomGrayscale(0.15),
        transforms.RandomAffine(degrees=10, translate=(0,0.1)),
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),

    ]),
    'test': transforms.Compose([
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

# %%
data_dir = '/kaggle/input/dtc314/data' # Suppose the dataset is stored under this folder
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'test']} # Read train and test sets, respectively.

train_dataloader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=128,
                                             shuffle=True, num_workers=4)

test_dataloader = torch.utils.data.DataLoader(image_datasets['test'], batch_size=128,
                                             shuffle=False, num_workers=4)

train_size =len(image_datasets['train'])


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # Set device to "cpu" if you have no gpu

# %%
history = dict()

def train_test(model, criterion, optimizer, scheduler, num_epochs=25):
    train_loss = []
    train_accuracy = []
    val_loss = [] 
    val_accuracy = []
    model.train()
    for epoch in range(num_epochs):
        running_training_loss = 0.0
        running_training_accuracy = 0.0
        iteration_training_loss = 0.0
        total_training_predictions = 0
       
        start_time = time.time()
        for i, data in enumerate(train_dataloader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_training_loss += loss.item()*inputs.size(0)
            
            _, predicted = torch.max(outputs.data, 1)
            total_training_predictions += labels.size(0)
            running_training_accuracy += (predicted == labels).sum().item()
            iteration_training_loss += loss.item() 
            if (i+1) % 100 == 0:
                print('Epoch:[%d]-Iteration:[%d], training loss: %.3f' %
                      (epoch + 1,i+1,iteration_training_loss/(i+1)))
        end_time = time.time()
        print('Time cost of one epoch: [%d]s' % (end_time-start_time))
        
        epoch_training_accuracy = running_training_accuracy / train_size*100
        epoch_training_loss = running_training_loss / train_size
        
        print('Epoch:[%d], training accuracy: %.1f, training loss: %.3f' %
              (epoch + 1,epoch_training_accuracy, epoch_training_loss))
        
        train_loss.append(epoch_training_loss)
        train_accuracy.append(epoch_training_accuracy)
        
        correct = 0
        total = 0
        labelsCorrect = [0 for i in range(10)]
        labelsTotal = [0 for i in range(10)]
        model.eval()
        # Since we're not training, we don't need to calculate the gradients for our outputs
        with torch.no_grad():
            for data in test_dataloader:
                images, labels = data[0].to(device), data[1].to(device)
                # calculate outputs by running images through the network
                outputs = model(images)
                # the class with the highest energy is what we choose as prediction
                _, predicted = torch.max(outputs.data, 1)
                tmp = (predicted == labels)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                for i in range(labels.size(0)): 
                    label = labels.data[i]
                    labelsCorrect[label] += tmp[i]
                    labelsTotal[label] += 1
        accuracy = float(100) * correct / total
        print(f'Accuracy of the network on test images: {accuracy}')
        for i in range(10): 
            acc = (labelsCorrect[i]/labelsTotal[i]).item
            print(f"Test Accuracy of {i}: {round((labelsCorrect[i]/labelsTotal[i]).item()*100,2)}")        
        val_accuracy.append(accuracy)
        scheduler.step()
        
    print('Finished Training')

    history['train_loss'] = train_loss
    history['train_accuracy'] = train_accuracy
    history['val_accuracy'] = val_accuracy

    return history, accuracy

# %%
epoch = 50

if __name__ == '__main__':
    end = time.time()
    model_ft = Net().to(device) # Model initialization
    print(model_ft.network)
    criterion = nn.CrossEntropyLoss() # Loss function initialization

    # TODO: Adjust the following hyper-parameters: initial learning rate, decay strategy of the learning rate, 
    #       number of training epochs
    optimizer_ft = optim.AdamW(model_ft.parameters(), lr=0.001, weight_decay=1)

    exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[20, 30], gamma=0.05) 
    
    history, accuracy = train_test(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
               num_epochs=epoch)
    
    print("time required %.2fs" %(time.time() - end))
# Out:
# Sequential(
#   (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (1): ReLU()
#   (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU()
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Dropout(p=0.3, inplace=False)
#   (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU()
#   (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU()
#   (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (11): Dropout(p=0.3, inplace=False)
#   (12): Flatten(start_dim=1, end_dim=-1)
#   (13): Linear(in_features=4096, out_features=128, bias=True)
#   (14): ReLU()
#   (15): Linear(in_features=128, out_features=10, bias=True)
# )
# Epoch:[1]-Iteration:[100], training loss: 2.303
# Epoch:[1]-Iteration:[200], training loss: 2.135
# Time cost of one epoch: [90]s
# Epoch:[1], training accuracy: 24.3, training loss: 2.030
# Accuracy of the network on test images: 64.92
# Test Accuracy of 0: 79.8
# Test Accuracy of 1: 81.0
# Test Accuracy of 2: 76.4
# Test Accuracy of 3: 34.0
# Test Accuracy of 4: 61.4
# Test Accuracy of 5: 22.6
# Test Accuracy of 6: 66.2
# Test Accuracy of 7: 86.6
# Test Accuracy of 8: 75.8
# Test Accuracy of 9: 65.4
# Epoch:[2]-Iteration:[100], training loss: 1.061
# Epoch:[2]-Iteration:[200], training loss: 0.937
# Time cost of one epoch: [87]s
# Epoch:[2], training accuracy: 70.7, training loss: 0.908
# Accuracy of the network on test images: 83.34
# Test Accuracy of 0: 90.2
# Test Accuracy of 1: 81.4
# Test Accuracy of 2: 81.2
# Test Accuracy of 3: 84.4
# Test Accuracy of 4: 83.8
# Test Accuracy of 5: 78.0
# Test Accuracy of 6: 85.2
# Test Accuracy of 7: 92.2
# Test Accuracy of 8: 66.6
# Test Accuracy of 9: 90.4
# Epoch:[3]-Iteration:[100], training loss: 0.696
# Epoch:[3]-Iteration:[200], training loss: 0.671
# Time cost of one epoch: [87]s
# Epoch:[3], training accuracy: 79.3, training loss: 0.661
# Accuracy of the network on test images: 87.06
# Test Accuracy of 0: 87.6
# Test Accuracy of 1: 91.6
# Test Accuracy of 2: 89.0
# Test Accuracy of 3: 87.2
# Test Accuracy of 4: 93.4
# Test Accuracy of 5: 82.0
# Test Accuracy of 6: 79.8
# Test Accuracy of 7: 90.2
# Test Accuracy of 8: 84.4
# Test Accuracy of 9: 85.4
# Epoch:[4]-Iteration:[100], training loss: 0.585
# Epoch:[4]-Iteration:[200], training loss: 0.578
# Time cost of one epoch: [90]s
# Epoch:[4], training accuracy: 82.1, training loss: 0.574
# Accuracy of the network on test images: 88.06
# Test Accuracy of 0: 95.0
# Test Accuracy of 1: 88.6
# Test Accuracy of 2: 86.2
# Test Accuracy of 3: 82.0
# Test Accuracy of 4: 91.4
# Test Accuracy of 5: 83.6
# Test Accuracy of 6: 88.0
# Test Accuracy of 7: 93.2
# Test Accuracy of 8: 88.6
# Test Accuracy of 9: 84.0
# Epoch:[5]-Iteration:[100], training loss: 0.546
# Epoch:[5]-Iteration:[200], training loss: 0.535
# Time cost of one epoch: [90]s
# Epoch:[5], training accuracy: 83.4, training loss: 0.535
# Accuracy of the network on test images: 88.04
# Test Accuracy of 0: 94.6
# Test Accuracy of 1: 86.2
# Test Accuracy of 2: 92.8
# Test Accuracy of 3: 86.0
# Test Accuracy of 4: 78.4
# Test Accuracy of 5: 86.6
# Test Accuracy of 6: 87.8
# Test Accuracy of 7: 91.0
# Test Accuracy of 8: 86.6
# Test Accuracy of 9: 90.4
# Epoch:[6]-Iteration:[100], training loss: 0.519
# Epoch:[6]-Iteration:[200], training loss: 0.509
# Time cost of one epoch: [89]s
# Epoch:[6], training accuracy: 84.3, training loss: 0.506
# Accuracy of the network on test images: 89.04
# Test Accuracy of 0: 93.8
# Test Accuracy of 1: 94.2
# Test Accuracy of 2: 88.4
# Test Accuracy of 3: 88.0
# Test Accuracy of 4: 89.0
# Test Accuracy of 5: 86.4
# Test Accuracy of 6: 89.4
# Test Accuracy of 7: 91.8
# Test Accuracy of 8: 80.8
# Test Accuracy of 9: 88.6
# Epoch:[7]-Iteration:[100], training loss: 0.490
# Epoch:[7]-Iteration:[200], training loss: 0.490
# Time cost of one epoch: [89]s
# Epoch:[7], training accuracy: 84.9, training loss: 0.490
# Accuracy of the network on test images: 89.5
# Test Accuracy of 0: 89.2
# Test Accuracy of 1: 89.6
# Test Accuracy of 2: 89.4
# Test Accuracy of 3: 86.0
# Test Accuracy of 4: 90.8
# Test Accuracy of 5: 85.8
# Test Accuracy of 6: 86.2
# Test Accuracy of 7: 92.8
# Test Accuracy of 8: 92.0
# Test Accuracy of 9: 93.2
# Epoch:[8]-Iteration:[100], training loss: 0.469
# Epoch:[8]-Iteration:[200], training loss: 0.474
# Time cost of one epoch: [89]s
# Epoch:[8], training accuracy: 85.5, training loss: 0.475
# Accuracy of the network on test images: 89.92
# Test Accuracy of 0: 85.0
# Test Accuracy of 1: 90.0
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 84.4
# Test Accuracy of 4: 91.8
# Test Accuracy of 5: 88.6
# Test Accuracy of 6: 85.4
# Test Accuracy of 7: 92.0
# Test Accuracy of 8: 93.6
# Test Accuracy of 9: 93.0
# Epoch:[9]-Iteration:[100], training loss: 0.456
# Epoch:[9]-Iteration:[200], training loss: 0.463
# Time cost of one epoch: [89]s
# Epoch:[9], training accuracy: 85.9, training loss: 0.462
# Accuracy of the network on test images: 90.4
# Test Accuracy of 0: 90.8
# Test Accuracy of 1: 91.0
# Test Accuracy of 2: 88.0
# Test Accuracy of 3: 89.6
# Test Accuracy of 4: 93.4
# Test Accuracy of 5: 88.8
# Test Accuracy of 6: 86.2
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 86.6
# Test Accuracy of 9: 94.8
# Epoch:[10]-Iteration:[100], training loss: 0.435
# Epoch:[10]-Iteration:[200], training loss: 0.444
# Time cost of one epoch: [89]s
# Epoch:[10], training accuracy: 86.3, training loss: 0.448
# Accuracy of the network on test images: 89.9
# Test Accuracy of 0: 90.8
# Test Accuracy of 1: 89.4
# Test Accuracy of 2: 90.2
# Test Accuracy of 3: 89.0
# Test Accuracy of 4: 92.6
# Test Accuracy of 5: 84.2
# Test Accuracy of 6: 88.2
# Test Accuracy of 7: 90.6
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 91.2
# Epoch:[11]-Iteration:[100], training loss: 0.433
# Epoch:[11]-Iteration:[200], training loss: 0.446
# Time cost of one epoch: [89]s
# Epoch:[11], training accuracy: 86.3, training loss: 0.446
# Accuracy of the network on test images: 90.48
# Test Accuracy of 0: 91.8
# Test Accuracy of 1: 90.8
# Test Accuracy of 2: 89.4
# Test Accuracy of 3: 81.8
# Test Accuracy of 4: 89.0
# Test Accuracy of 5: 93.0
# Test Accuracy of 6: 92.0
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 87.8
# Test Accuracy of 9: 93.6
# Epoch:[12]-Iteration:[100], training loss: 0.430
# Epoch:[12]-Iteration:[200], training loss: 0.436
# Time cost of one epoch: [89]s
# Epoch:[12], training accuracy: 86.6, training loss: 0.439
# Accuracy of the network on test images: 90.68
# Test Accuracy of 0: 92.4
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 92.2
# Test Accuracy of 3: 91.2
# Test Accuracy of 4: 90.8
# Test Accuracy of 5: 86.8
# Test Accuracy of 6: 89.6
# Test Accuracy of 7: 92.8
# Test Accuracy of 8: 91.4
# Test Accuracy of 9: 86.4
# Epoch:[13]-Iteration:[100], training loss: 0.422
# Epoch:[13]-Iteration:[200], training loss: 0.429
# Time cost of one epoch: [89]s
# Epoch:[13], training accuracy: 86.9, training loss: 0.431
# Accuracy of the network on test images: 90.7
# Test Accuracy of 0: 89.6
# Test Accuracy of 1: 90.6
# Test Accuracy of 2: 93.2
# Test Accuracy of 3: 85.6
# Test Accuracy of 4: 88.4
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 91.6
# Test Accuracy of 7: 92.0
# Test Accuracy of 8: 92.4
# Test Accuracy of 9: 91.2
# Epoch:[14]-Iteration:[100], training loss: 0.420
# Epoch:[14]-Iteration:[200], training loss: 0.430
# Time cost of one epoch: [90]s
# Epoch:[14], training accuracy: 86.8, training loss: 0.431
# Accuracy of the network on test images: 89.92
# Test Accuracy of 0: 88.0
# Test Accuracy of 1: 90.8
# Test Accuracy of 2: 95.0
# Test Accuracy of 3: 84.6
# Test Accuracy of 4: 93.4
# Test Accuracy of 5: 94.8
# Test Accuracy of 6: 86.4
# Test Accuracy of 7: 92.8
# Test Accuracy of 8: 83.8
# Test Accuracy of 9: 89.6
# Epoch:[15]-Iteration:[100], training loss: 0.427
# Epoch:[15]-Iteration:[200], training loss: 0.422
# Time cost of one epoch: [89]s
# Epoch:[15], training accuracy: 87.1, training loss: 0.425
# Accuracy of the network on test images: 91.12
# Test Accuracy of 0: 91.0
# Test Accuracy of 1: 94.0
# Test Accuracy of 2: 91.8
# Test Accuracy of 3: 82.4
# Test Accuracy of 4: 93.2
# Test Accuracy of 5: 92.6
# Test Accuracy of 6: 92.6
# Test Accuracy of 7: 92.4
# Test Accuracy of 8: 90.0
# Test Accuracy of 9: 91.2
# Epoch:[16]-Iteration:[100], training loss: 0.411
# Epoch:[16]-Iteration:[200], training loss: 0.417
# Time cost of one epoch: [90]s
# Epoch:[16], training accuracy: 87.2, training loss: 0.420
# Accuracy of the network on test images: 91.24
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 92.8
# Test Accuracy of 2: 91.4
# Test Accuracy of 3: 84.8
# Test Accuracy of 4: 93.0
# Test Accuracy of 5: 89.8
# Test Accuracy of 6: 93.0
# Test Accuracy of 7: 90.2
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 91.4
# Epoch:[17]-Iteration:[100], training loss: 0.412
# Epoch:[17]-Iteration:[200], training loss: 0.416
# Time cost of one epoch: [90]s
# Epoch:[17], training accuracy: 87.4, training loss: 0.414
# Accuracy of the network on test images: 90.76
# Test Accuracy of 0: 92.8
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 88.6
# Test Accuracy of 3: 85.4
# Test Accuracy of 4: 92.8
# Test Accuracy of 5: 90.2
# Test Accuracy of 6: 89.6
# Test Accuracy of 7: 91.6
# Test Accuracy of 8: 93.4
# Test Accuracy of 9: 91.2
# Epoch:[18]-Iteration:[100], training loss: 0.412
# Epoch:[18]-Iteration:[200], training loss: 0.411
# Time cost of one epoch: [89]s
# Epoch:[18], training accuracy: 87.4, training loss: 0.413
# Accuracy of the network on test images: 90.88
# Test Accuracy of 0: 91.6
# Test Accuracy of 1: 93.0
# Test Accuracy of 2: 93.2
# Test Accuracy of 3: 87.0
# Test Accuracy of 4: 92.4
# Test Accuracy of 5: 89.6
# Test Accuracy of 6: 90.6
# Test Accuracy of 7: 85.4
# Test Accuracy of 8: 93.0
# Test Accuracy of 9: 93.0
# Epoch:[19]-Iteration:[100], training loss: 0.412
# Epoch:[19]-Iteration:[200], training loss: 0.418
# Time cost of one epoch: [89]s
# Epoch:[19], training accuracy: 87.1, training loss: 0.420
# Accuracy of the network on test images: 90.02
# Test Accuracy of 0: 94.0
# Test Accuracy of 1: 89.8
# Test Accuracy of 2: 94.8
# Test Accuracy of 3: 88.6
# Test Accuracy of 4: 89.6
# Test Accuracy of 5: 81.6
# Test Accuracy of 6: 84.4
# Test Accuracy of 7: 92.4
# Test Accuracy of 8: 94.4
# Test Accuracy of 9: 90.6
# Epoch:[20]-Iteration:[100], training loss: 0.404
# Epoch:[20]-Iteration:[200], training loss: 0.406
# Time cost of one epoch: [89]s
# Epoch:[20], training accuracy: 87.8, training loss: 0.407
# Accuracy of the network on test images: 90.48
# Test Accuracy of 0: 94.4
# Test Accuracy of 1: 83.8
# Test Accuracy of 2: 88.0
# Test Accuracy of 3: 93.8
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 85.0
# Test Accuracy of 6: 88.6
# Test Accuracy of 7: 96.6
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 87.6
# Epoch:[21]-Iteration:[100], training loss: 0.359
# Epoch:[21]-Iteration:[200], training loss: 0.349
# Time cost of one epoch: [89]s
# Epoch:[21], training accuracy: 89.5, training loss: 0.349
# Accuracy of the network on test images: 92.44
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 92.8
# Test Accuracy of 2: 94.0
# Test Accuracy of 3: 89.0
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 92.8
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 90.0
# Test Accuracy of 9: 91.8
# Epoch:[22]-Iteration:[100], training loss: 0.328
# Epoch:[22]-Iteration:[200], training loss: 0.325
# Time cost of one epoch: [90]s
# Epoch:[22], training accuracy: 90.1, training loss: 0.329
# Accuracy of the network on test images: 92.26
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 93.0
# Test Accuracy of 3: 86.8
# Test Accuracy of 4: 94.4
# Test Accuracy of 5: 89.6
# Test Accuracy of 6: 92.8
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 90.4
# Test Accuracy of 9: 93.2
# Epoch:[23]-Iteration:[100], training loss: 0.332
# Epoch:[23]-Iteration:[200], training loss: 0.333
# Time cost of one epoch: [89]s
# Epoch:[23], training accuracy: 90.2, training loss: 0.328
# Accuracy of the network on test images: 92.68
# Test Accuracy of 0: 92.6
# Test Accuracy of 1: 92.4
# Test Accuracy of 2: 92.8
# Test Accuracy of 3: 88.2
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 91.0
# Test Accuracy of 6: 94.0
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 94.0
# Epoch:[24]-Iteration:[100], training loss: 0.319
# Epoch:[24]-Iteration:[200], training loss: 0.325
# Time cost of one epoch: [89]s
# Epoch:[24], training accuracy: 90.4, training loss: 0.322
# Accuracy of the network on test images: 92.58
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 91.6
# Test Accuracy of 2: 92.8
# Test Accuracy of 3: 88.6
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 91.2
# Test Accuracy of 6: 94.2
# Test Accuracy of 7: 94.2
# Test Accuracy of 8: 90.8
# Test Accuracy of 9: 93.6
# Epoch:[25]-Iteration:[100], training loss: 0.322
# Epoch:[25]-Iteration:[200], training loss: 0.318
# Time cost of one epoch: [88]s
# Epoch:[25], training accuracy: 90.7, training loss: 0.319
# Accuracy of the network on test images: 92.86
# Test Accuracy of 0: 94.0
# Test Accuracy of 1: 92.6
# Test Accuracy of 2: 92.4
# Test Accuracy of 3: 90.4
# Test Accuracy of 4: 93.8
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 94.0
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 94.6
# Epoch:[26]-Iteration:[100], training loss: 0.315
# Epoch:[26]-Iteration:[200], training loss: 0.319
# Time cost of one epoch: [89]s
# Epoch:[26], training accuracy: 90.4, training loss: 0.321
# Accuracy of the network on test images: 92.72
# Test Accuracy of 0: 93.8
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 92.6
# Test Accuracy of 3: 88.6
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 90.8
# Test Accuracy of 6: 93.0
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 94.8
# Epoch:[27]-Iteration:[100], training loss: 0.317
# Epoch:[27]-Iteration:[200], training loss: 0.316
# Time cost of one epoch: [90]s
# Epoch:[27], training accuracy: 90.6, training loss: 0.317
# Accuracy of the network on test images: 92.5
# Test Accuracy of 0: 93.0
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 92.6
# Test Accuracy of 3: 86.0
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 91.2
# Test Accuracy of 6: 94.2
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 93.8
# Epoch:[28]-Iteration:[100], training loss: 0.312
# Epoch:[28]-Iteration:[200], training loss: 0.313
# Time cost of one epoch: [89]s
# Epoch:[28], training accuracy: 90.8, training loss: 0.314
# Accuracy of the network on test images: 92.52
# Test Accuracy of 0: 95.2
# Test Accuracy of 1: 92.4
# Test Accuracy of 2: 93.2
# Test Accuracy of 3: 89.2
# Test Accuracy of 4: 94.2
# Test Accuracy of 5: 90.2
# Test Accuracy of 6: 93.0
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 90.8
# Test Accuracy of 9: 91.8
# Epoch:[29]-Iteration:[100], training loss: 0.316
# Epoch:[29]-Iteration:[200], training loss: 0.314
# Time cost of one epoch: [88]s
# Epoch:[29], training accuracy: 90.7, training loss: 0.315
# Accuracy of the network on test images: 92.68
# Test Accuracy of 0: 93.8
# Test Accuracy of 1: 92.2
# Test Accuracy of 2: 93.0
# Test Accuracy of 3: 88.8
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 89.2
# Test Accuracy of 6: 93.2
# Test Accuracy of 7: 96.0
# Test Accuracy of 8: 92.0
# Test Accuracy of 9: 93.4
# Epoch:[30]-Iteration:[100], training loss: 0.309
# Epoch:[30]-Iteration:[200], training loss: 0.310
# Time cost of one epoch: [89]s
# Epoch:[30], training accuracy: 90.7, training loss: 0.314
# Accuracy of the network on test images: 92.88
# Test Accuracy of 0: 94.2
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 93.2
# Test Accuracy of 3: 88.2
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 94.6
# Epoch:[31]-Iteration:[100], training loss: 0.310
# Epoch:[31]-Iteration:[200], training loss: 0.308
# Time cost of one epoch: [89]s
# Epoch:[31], training accuracy: 90.9, training loss: 0.308
# Accuracy of the network on test images: 92.76
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 91.8
# Test Accuracy of 2: 93.2
# Test Accuracy of 3: 88.4
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 92.0
# Test Accuracy of 9: 94.0
# Epoch:[32]-Iteration:[100], training loss: 0.307
# Epoch:[32]-Iteration:[200], training loss: 0.307
# Time cost of one epoch: [88]s
# Epoch:[32], training accuracy: 90.8, training loss: 0.308
# Accuracy of the network on test images: 92.82
# Test Accuracy of 0: 93.8
# Test Accuracy of 1: 91.8
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 88.6
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 91.8
# Test Accuracy of 9: 94.0
# Epoch:[33]-Iteration:[100], training loss: 0.300
# Epoch:[33]-Iteration:[200], training loss: 0.303
# Time cost of one epoch: [89]s
# Epoch:[33], training accuracy: 91.1, training loss: 0.305
# Accuracy of the network on test images: 92.8
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 92.2
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.6
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 93.8
# Epoch:[34]-Iteration:[100], training loss: 0.302
# Epoch:[34]-Iteration:[200], training loss: 0.303
# Time cost of one epoch: [88]s
# Epoch:[34], training accuracy: 91.1, training loss: 0.307
# Accuracy of the network on test images: 92.78
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 92.2
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.6
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 92.0
# Test Accuracy of 9: 94.0
# Epoch:[35]-Iteration:[100], training loss: 0.312
# Epoch:[35]-Iteration:[200], training loss: 0.305
# Time cost of one epoch: [88]s
# Epoch:[35], training accuracy: 91.0, training loss: 0.305
# Accuracy of the network on test images: 92.7
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.4
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 90.2
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 91.8
# Test Accuracy of 9: 93.8
# Epoch:[36]-Iteration:[100], training loss: 0.305
# Epoch:[36]-Iteration:[200], training loss: 0.306
# Time cost of one epoch: [89]s
# Epoch:[36], training accuracy: 90.9, training loss: 0.305
# Accuracy of the network on test images: 92.76
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.4
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 90.6
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 94.0
# Epoch:[37]-Iteration:[100], training loss: 0.300
# Epoch:[37]-Iteration:[200], training loss: 0.306
# Time cost of one epoch: [89]s
# Epoch:[37], training accuracy: 91.0, training loss: 0.305
# Accuracy of the network on test images: 92.74
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.4
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 91.4
# Test Accuracy of 9: 94.2
# Epoch:[38]-Iteration:[100], training loss: 0.310
# Epoch:[38]-Iteration:[200], training loss: 0.307
# Time cost of one epoch: [89]s
# Epoch:[38], training accuracy: 91.1, training loss: 0.304
# Accuracy of the network on test images: 92.88
# Test Accuracy of 0: 94.2
# Test Accuracy of 1: 92.2
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.8
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 90.2
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 94.0
# Epoch:[39]-Iteration:[100], training loss: 0.303
# Epoch:[39]-Iteration:[200], training loss: 0.306
# Time cost of one epoch: [89]s
# Epoch:[39], training accuracy: 91.1, training loss: 0.305
# Accuracy of the network on test images: 92.78
# Test Accuracy of 0: 94.0
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.4
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 94.0
# Epoch:[40]-Iteration:[100], training loss: 0.309
# Epoch:[40]-Iteration:[200], training loss: 0.302
# Time cost of one epoch: [90]s
# Epoch:[40], training accuracy: 91.0, training loss: 0.305
# Accuracy of the network on test images: 92.8
# Test Accuracy of 0: 93.8
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.6
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 90.6
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 94.2
# Epoch:[41]-Iteration:[100], training loss: 0.307
# Epoch:[41]-Iteration:[200], training loss: 0.302
# Time cost of one epoch: [88]s
# Epoch:[41], training accuracy: 91.1, training loss: 0.305
# Accuracy of the network on test images: 92.74
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.8
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 91.8
# Test Accuracy of 9: 94.2
# Epoch:[42]-Iteration:[100], training loss: 0.306
# Epoch:[42]-Iteration:[200], training loss: 0.307
# Time cost of one epoch: [88]s
# Epoch:[42], training accuracy: 90.9, training loss: 0.304
# Accuracy of the network on test images: 92.86
# Test Accuracy of 0: 93.8
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 88.6
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 90.6
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 94.2
# Epoch:[43]-Iteration:[100], training loss: 0.309
# Epoch:[43]-Iteration:[200], training loss: 0.305
# Time cost of one epoch: [88]s
# Epoch:[43], training accuracy: 91.1, training loss: 0.303
# Accuracy of the network on test images: 92.84
# Test Accuracy of 0: 94.0
# Test Accuracy of 1: 92.2
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.8
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 90.2
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 91.8
# Test Accuracy of 9: 94.0
# Epoch:[44]-Iteration:[100], training loss: 0.305
# Epoch:[44]-Iteration:[200], training loss: 0.306
# Time cost of one epoch: [89]s
# Epoch:[44], training accuracy: 91.2, training loss: 0.304
# Accuracy of the network on test images: 92.78
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 92.2
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.6
# Test Accuracy of 4: 94.4
# Test Accuracy of 5: 90.6
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 91.8
# Test Accuracy of 9: 94.2
# Epoch:[45]-Iteration:[100], training loss: 0.296
# Epoch:[45]-Iteration:[200], training loss: 0.302
# Time cost of one epoch: [89]s
# Epoch:[45], training accuracy: 91.2, training loss: 0.301
# Accuracy of the network on test images: 92.86
# Test Accuracy of 0: 94.0
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.8
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 92.4
# Test Accuracy of 9: 94.0
# Epoch:[46]-Iteration:[100], training loss: 0.305
# Epoch:[46]-Iteration:[200], training loss: 0.302
# Time cost of one epoch: [89]s
# Epoch:[46], training accuracy: 91.1, training loss: 0.303
# Accuracy of the network on test images: 92.76
# Test Accuracy of 0: 94.0
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.6
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 91.8
# Test Accuracy of 9: 93.8
# Epoch:[47]-Iteration:[100], training loss: 0.296
# Epoch:[47]-Iteration:[200], training loss: 0.300
# Time cost of one epoch: [89]s
# Epoch:[47], training accuracy: 91.1, training loss: 0.300
# Accuracy of the network on test images: 92.78
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 92.2
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.6
# Test Accuracy of 4: 94.2
# Test Accuracy of 5: 90.6
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 94.0
# Epoch:[48]-Iteration:[100], training loss: 0.305
# Epoch:[48]-Iteration:[200], training loss: 0.306
# Time cost of one epoch: [89]s
# Epoch:[48], training accuracy: 90.8, training loss: 0.307
# Accuracy of the network on test images: 92.86
# Test Accuracy of 0: 94.0
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.8
# Test Accuracy of 4: 94.4
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 94.0
# Epoch:[49]-Iteration:[100], training loss: 0.306
# Epoch:[49]-Iteration:[200], training loss: 0.307
# Time cost of one epoch: [88]s
# Epoch:[49], training accuracy: 91.0, training loss: 0.305
# Accuracy of the network on test images: 92.8
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.8
# Test Accuracy of 4: 94.4
# Test Accuracy of 5: 90.6
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 92.0
# Test Accuracy of 9: 94.2
# Epoch:[50]-Iteration:[100], training loss: 0.301
# Epoch:[50]-Iteration:[200], training loss: 0.303
# Time cost of one epoch: [89]s
# Epoch:[50], training accuracy: 91.3, training loss: 0.302
# Accuracy of the network on test images: 92.8
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 92.2
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 88.6
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 90.6
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.0
# Test Accuracy of 9: 94.2
# Finished Training
# time required 4723.09s

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(list(range(1,epoch+1)), history["train_accuracy"], label="Train")
plt.plot(list(range(1,epoch+1)), history["val_accuracy"], label="Test")
plt.xlabel("Epoch")
ax = plt.gca()
ax.set_ylim([90, 95])
plt.ylabel("Accuracy")
plt.legend()
plt.show()
print("Epoch with max test accuracy:", history["val_accuracy"].index(min(history["val_accuracy"]))+1)
# Out:
# Epoch with max test accuracy: 1
