# %%
from __future__ import print_function, division

import torch
import torch.optim as optim

from torch.optim import lr_scheduler
from torchvision import datasets, transforms
import time
import os

import torch.nn as nn

# TODO: You can modify the network architecture
class Net(nn.Module):
    """
    Input - 1x32x32
    Output - 10
    """
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=7, padding=3, stride=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(p=0.3),

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(p=0.3),

            nn.Flatten(), 
            nn.Linear(256*4*4, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
            )
        
    def forward(self, xb):
        return self.network(xb)

# %%
from random import randrange
# TODO: You can try different augmentation strategies
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomChoice([transforms.Pad(padding=4, fill=(randrange(256),randrange(256),randrange(256))), transforms.ElasticTransform(),transforms.GaussianBlur((3,3))]),
        transforms.RandomGrayscale(0.15),
        transforms.RandomAffine(degrees=10, translate=(0,0.1)),
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),

    ]),
    'test': transforms.Compose([
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

# %%
data_dir = '/kaggle/input/dtc314/data' # Suppose the dataset is stored under this folder
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'test']} # Read train and test sets, respectively.

train_dataloader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=128,
                                             shuffle=True, num_workers=4)

test_dataloader = torch.utils.data.DataLoader(image_datasets['test'], batch_size=128,
                                             shuffle=False, num_workers=4)

train_size =len(image_datasets['train'])


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # Set device to "cpu" if you have no gpu

# %%
history = dict()

def train_test(model, criterion, optimizer, scheduler, num_epochs=25):
    train_loss = []
    train_accuracy = []
    val_loss = [] 
    val_accuracy = []
    model.train()
    for epoch in range(num_epochs):
        running_training_loss = 0.0
        running_training_accuracy = 0.0
        iteration_training_loss = 0.0
        total_training_predictions = 0
       
        start_time = time.time()
        for i, data in enumerate(train_dataloader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_training_loss += loss.item()*inputs.size(0)
            
            _, predicted = torch.max(outputs.data, 1)
            total_training_predictions += labels.size(0)
            running_training_accuracy += (predicted == labels).sum().item()
            iteration_training_loss += loss.item() 
            if (i+1) % 100 == 0:
                print('Epoch:[%d]-Iteration:[%d], training loss: %.3f' %
                      (epoch + 1,i+1,iteration_training_loss/(i+1)))
        end_time = time.time()
        print('Time cost of one epoch: [%d]s' % (end_time-start_time))
        
        epoch_training_accuracy = running_training_accuracy / train_size*100
        epoch_training_loss = running_training_loss / train_size
        
        print('Epoch:[%d], training accuracy: %.1f, training loss: %.3f' %
              (epoch + 1,epoch_training_accuracy, epoch_training_loss))
        
        train_loss.append(epoch_training_loss)
        train_accuracy.append(epoch_training_accuracy)
        
        correct = 0
        total = 0
        labelsCorrect = [0 for i in range(10)]
        labelsTotal = [0 for i in range(10)]
        model.eval()
        # Since we're not training, we don't need to calculate the gradients for our outputs
        with torch.no_grad():
            for data in test_dataloader:
                images, labels = data[0].to(device), data[1].to(device)
                # calculate outputs by running images through the network
                outputs = model(images)
                # the class with the highest energy is what we choose as prediction
                _, predicted = torch.max(outputs.data, 1)
                tmp = (predicted == labels)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                for i in range(labels.size(0)): 
                    label = labels.data[i]
                    labelsCorrect[label] += tmp[i]
                    labelsTotal[label] += 1
        accuracy = float(100) * correct / total
        print(f'Accuracy of the network on test images: {accuracy}')
        for i in range(10): 
            acc = (labelsCorrect[i]/labelsTotal[i]).item
            print(f"Test Accuracy of {i}: {round((labelsCorrect[i]/labelsTotal[i]).item()*100,2)}")        
        val_accuracy.append(accuracy)
        scheduler.step()
        
    print('Finished Training')

    history['train_loss'] = train_loss
    history['train_accuracy'] = train_accuracy
    history['val_accuracy'] = val_accuracy

    return history, accuracy

# %%
epoch = 50

if __name__ == '__main__':
    end = time.time()
    model_ft = Net().to(device) # Model initialization
    print(model_ft.network)
    criterion = nn.CrossEntropyLoss() # Loss function initialization

    # TODO: Adjust the following hyper-parameters: initial learning rate, decay strategy of the learning rate, 
    #       number of training epochs
    optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.001) # The initial learning rate is 1e-3

    exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=15, gamma=0.05) 
    
    history, accuracy = train_test(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
               num_epochs=epoch)
    
    print("time required %.2fs" %(time.time() - end))
# Out:
# Sequential(
#   (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (1): ReLU()
#   (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU()
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Dropout(p=0.3, inplace=False)
#   (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU()
#   (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU()
#   (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (11): Dropout(p=0.3, inplace=False)
#   (12): Flatten(start_dim=1, end_dim=-1)
#   (13): Linear(in_features=4096, out_features=128, bias=True)
#   (14): ReLU()
#   (15): Linear(in_features=128, out_features=10, bias=True)
# )
# Epoch:[1]-Iteration:[100], training loss: 2.303
# Epoch:[1]-Iteration:[200], training loss: 2.126
# Time cost of one epoch: [88]s
# Epoch:[1], training accuracy: 24.6, training loss: 2.014
# Accuracy of the network on test images: 71.22
# Test Accuracy of 0: 85.8
# Test Accuracy of 1: 82.2
# Test Accuracy of 2: 79.2
# Test Accuracy of 3: 44.2
# Test Accuracy of 4: 76.8
# Test Accuracy of 5: 67.2
# Test Accuracy of 6: 64.4
# Test Accuracy of 7: 76.2
# Test Accuracy of 8: 63.6
# Test Accuracy of 9: 72.6
# Epoch:[2]-Iteration:[100], training loss: 0.993
# Epoch:[2]-Iteration:[200], training loss: 0.874
# Time cost of one epoch: [88]s
# Epoch:[2], training accuracy: 72.8, training loss: 0.848
# Accuracy of the network on test images: 85.26
# Test Accuracy of 0: 89.2
# Test Accuracy of 1: 86.0
# Test Accuracy of 2: 91.2
# Test Accuracy of 3: 76.8
# Test Accuracy of 4: 88.6
# Test Accuracy of 5: 82.4
# Test Accuracy of 6: 77.6
# Test Accuracy of 7: 92.2
# Test Accuracy of 8: 85.6
# Test Accuracy of 9: 83.0
# Epoch:[3]-Iteration:[100], training loss: 0.622
# Epoch:[3]-Iteration:[200], training loss: 0.596
# Time cost of one epoch: [89]s
# Epoch:[3], training accuracy: 81.7, training loss: 0.584
# Accuracy of the network on test images: 88.14
# Test Accuracy of 0: 93.0
# Test Accuracy of 1: 88.4
# Test Accuracy of 2: 86.8
# Test Accuracy of 3: 83.8
# Test Accuracy of 4: 89.8
# Test Accuracy of 5: 85.4
# Test Accuracy of 6: 89.2
# Test Accuracy of 7: 90.8
# Test Accuracy of 8: 79.4
# Test Accuracy of 9: 94.8
# Epoch:[4]-Iteration:[100], training loss: 0.521
# Epoch:[4]-Iteration:[200], training loss: 0.502
# Time cost of one epoch: [90]s
# Epoch:[4], training accuracy: 84.6, training loss: 0.497
# Accuracy of the network on test images: 89.72
# Test Accuracy of 0: 92.8
# Test Accuracy of 1: 88.2
# Test Accuracy of 2: 89.4
# Test Accuracy of 3: 85.2
# Test Accuracy of 4: 92.8
# Test Accuracy of 5: 90.8
# Test Accuracy of 6: 87.0
# Test Accuracy of 7: 92.6
# Test Accuracy of 8: 87.2
# Test Accuracy of 9: 91.2
# Epoch:[5]-Iteration:[100], training loss: 0.450
# Epoch:[5]-Iteration:[200], training loss: 0.445
# Time cost of one epoch: [90]s
# Epoch:[5], training accuracy: 86.2, training loss: 0.441
# Accuracy of the network on test images: 90.14
# Test Accuracy of 0: 91.8
# Test Accuracy of 1: 90.0
# Test Accuracy of 2: 90.0
# Test Accuracy of 3: 85.8
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 87.8
# Test Accuracy of 6: 85.4
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 88.2
# Test Accuracy of 9: 92.6
# Epoch:[6]-Iteration:[100], training loss: 0.403
# Epoch:[6]-Iteration:[200], training loss: 0.408
# Time cost of one epoch: [89]s
# Epoch:[6], training accuracy: 87.4, training loss: 0.409
# Accuracy of the network on test images: 90.78
# Test Accuracy of 0: 91.0
# Test Accuracy of 1: 91.0
# Test Accuracy of 2: 90.8
# Test Accuracy of 3: 83.6
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 92.6
# Test Accuracy of 6: 91.0
# Test Accuracy of 7: 94.0
# Test Accuracy of 8: 85.8
# Test Accuracy of 9: 93.4
# Epoch:[7]-Iteration:[100], training loss: 0.370
# Epoch:[7]-Iteration:[200], training loss: 0.380
# Time cost of one epoch: [89]s
# Epoch:[7], training accuracy: 88.4, training loss: 0.379
# Accuracy of the network on test images: 91.5
# Test Accuracy of 0: 96.0
# Test Accuracy of 1: 88.0
# Test Accuracy of 2: 95.2
# Test Accuracy of 3: 88.8
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 89.0
# Test Accuracy of 6: 92.6
# Test Accuracy of 7: 93.2
# Test Accuracy of 8: 88.2
# Test Accuracy of 9: 89.2
# Epoch:[8]-Iteration:[100], training loss: 0.358
# Epoch:[8]-Iteration:[200], training loss: 0.363
# Time cost of one epoch: [89]s
# Epoch:[8], training accuracy: 88.9, training loss: 0.361
# Accuracy of the network on test images: 91.68
# Test Accuracy of 0: 94.2
# Test Accuracy of 1: 89.0
# Test Accuracy of 2: 92.4
# Test Accuracy of 3: 87.6
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 90.6
# Test Accuracy of 6: 95.4
# Test Accuracy of 7: 94.6
# Test Accuracy of 8: 85.4
# Test Accuracy of 9: 92.8
# Epoch:[9]-Iteration:[100], training loss: 0.335
# Epoch:[9]-Iteration:[200], training loss: 0.334
# Time cost of one epoch: [89]s
# Epoch:[9], training accuracy: 89.8, training loss: 0.334
# Accuracy of the network on test images: 91.28
# Test Accuracy of 0: 91.0
# Test Accuracy of 1: 91.6
# Test Accuracy of 2: 94.0
# Test Accuracy of 3: 83.2
# Test Accuracy of 4: 93.8
# Test Accuracy of 5: 91.6
# Test Accuracy of 6: 90.6
# Test Accuracy of 7: 92.4
# Test Accuracy of 8: 92.0
# Test Accuracy of 9: 92.6
# Epoch:[10]-Iteration:[100], training loss: 0.322
# Epoch:[10]-Iteration:[200], training loss: 0.322
# Time cost of one epoch: [90]s
# Epoch:[10], training accuracy: 90.1, training loss: 0.324
# Accuracy of the network on test images: 91.4
# Test Accuracy of 0: 89.4
# Test Accuracy of 1: 93.6
# Test Accuracy of 2: 91.4
# Test Accuracy of 3: 85.2
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 93.4
# Test Accuracy of 6: 91.6
# Test Accuracy of 7: 96.2
# Test Accuracy of 8: 85.8
# Test Accuracy of 9: 90.8
# Epoch:[11]-Iteration:[100], training loss: 0.308
# Epoch:[11]-Iteration:[200], training loss: 0.305
# Time cost of one epoch: [90]s
# Epoch:[11], training accuracy: 90.5, training loss: 0.309
# Accuracy of the network on test images: 91.54
# Test Accuracy of 0: 89.6
# Test Accuracy of 1: 90.8
# Test Accuracy of 2: 93.8
# Test Accuracy of 3: 87.0
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 88.8
# Test Accuracy of 6: 92.6
# Test Accuracy of 7: 96.4
# Test Accuracy of 8: 88.6
# Test Accuracy of 9: 92.6
# Epoch:[12]-Iteration:[100], training loss: 0.286
# Epoch:[12]-Iteration:[200], training loss: 0.295
# Time cost of one epoch: [89]s
# Epoch:[12], training accuracy: 90.8, training loss: 0.298
# Accuracy of the network on test images: 91.94
# Test Accuracy of 0: 94.8
# Test Accuracy of 1: 93.0
# Test Accuracy of 2: 91.4
# Test Accuracy of 3: 86.8
# Test Accuracy of 4: 94.2
# Test Accuracy of 5: 92.8
# Test Accuracy of 6: 91.6
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 87.4
# Test Accuracy of 9: 92.0
# Epoch:[13]-Iteration:[100], training loss: 0.284
# Epoch:[13]-Iteration:[200], training loss: 0.287
# Time cost of one epoch: [89]s
# Epoch:[13], training accuracy: 91.1, training loss: 0.289
# Accuracy of the network on test images: 91.46
# Test Accuracy of 0: 92.6
# Test Accuracy of 1: 87.0
# Test Accuracy of 2: 96.4
# Test Accuracy of 3: 89.6
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 89.0
# Test Accuracy of 7: 88.8
# Test Accuracy of 8: 95.4
# Test Accuracy of 9: 90.8
# Epoch:[14]-Iteration:[100], training loss: 0.273
# Epoch:[14]-Iteration:[200], training loss: 0.276
# Time cost of one epoch: [89]s
# Epoch:[14], training accuracy: 91.1, training loss: 0.279
# Accuracy of the network on test images: 92.54
# Test Accuracy of 0: 92.0
# Test Accuracy of 1: 91.4
# Test Accuracy of 2: 94.4
# Test Accuracy of 3: 87.4
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 91.4
# Test Accuracy of 6: 92.4
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.4
# Test Accuracy of 9: 93.6
# Epoch:[15]-Iteration:[100], training loss: 0.278
# Epoch:[15]-Iteration:[200], training loss: 0.271
# Time cost of one epoch: [89]s
# Epoch:[15], training accuracy: 91.7, training loss: 0.271
# Accuracy of the network on test images: 92.3
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 92.6
# Test Accuracy of 2: 93.8
# Test Accuracy of 3: 84.0
# Test Accuracy of 4: 97.0
# Test Accuracy of 5: 95.8
# Test Accuracy of 6: 92.0
# Test Accuracy of 7: 92.4
# Test Accuracy of 8: 89.4
# Test Accuracy of 9: 92.6
# Epoch:[16]-Iteration:[100], training loss: 0.237
# Epoch:[16]-Iteration:[200], training loss: 0.225
# Time cost of one epoch: [89]s
# Epoch:[16], training accuracy: 93.1, training loss: 0.223
# Accuracy of the network on test images: 93.3
# Test Accuracy of 0: 93.2
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 94.2
# Test Accuracy of 3: 90.0
# Test Accuracy of 4: 96.2
# Test Accuracy of 5: 90.8
# Test Accuracy of 6: 93.2
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 94.2
# Epoch:[17]-Iteration:[100], training loss: 0.209
# Epoch:[17]-Iteration:[200], training loss: 0.209
# Time cost of one epoch: [89]s
# Epoch:[17], training accuracy: 93.8, training loss: 0.208
# Accuracy of the network on test images: 93.24
# Test Accuracy of 0: 93.0
# Test Accuracy of 1: 92.8
# Test Accuracy of 2: 95.0
# Test Accuracy of 3: 89.4
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 91.6
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 92.4
# Test Accuracy of 9: 94.2
# Epoch:[18]-Iteration:[100], training loss: 0.201
# Epoch:[18]-Iteration:[200], training loss: 0.205
# Time cost of one epoch: [89]s
# Epoch:[18], training accuracy: 93.7, training loss: 0.204
# Accuracy of the network on test images: 93.36
# Test Accuracy of 0: 93.0
# Test Accuracy of 1: 94.0
# Test Accuracy of 2: 94.6
# Test Accuracy of 3: 89.2
# Test Accuracy of 4: 96.2
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 92.4
# Test Accuracy of 9: 93.6
# Epoch:[19]-Iteration:[100], training loss: 0.203
# Epoch:[19]-Iteration:[200], training loss: 0.202
# Time cost of one epoch: [90]s
# Epoch:[19], training accuracy: 93.8, training loss: 0.203
# Accuracy of the network on test images: 93.5
# Test Accuracy of 0: 93.0
# Test Accuracy of 1: 93.0
# Test Accuracy of 2: 95.2
# Test Accuracy of 3: 90.0
# Test Accuracy of 4: 96.0
# Test Accuracy of 5: 91.6
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 93.4
# Test Accuracy of 9: 93.6
# Epoch:[20]-Iteration:[100], training loss: 0.197
# Epoch:[20]-Iteration:[200], training loss: 0.196
# Time cost of one epoch: [90]s
# Epoch:[20], training accuracy: 94.1, training loss: 0.198
# Accuracy of the network on test images: 93.48
# Test Accuracy of 0: 92.6
# Test Accuracy of 1: 93.6
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.0
# Test Accuracy of 4: 96.0
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 93.2
# Test Accuracy of 9: 93.2
# Epoch:[21]-Iteration:[100], training loss: 0.201
# Epoch:[21]-Iteration:[200], training loss: 0.196
# Time cost of one epoch: [89]s
# Epoch:[21], training accuracy: 94.1, training loss: 0.195
# Accuracy of the network on test images: 93.56
# Test Accuracy of 0: 93.0
# Test Accuracy of 1: 93.6
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.6
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 91.4
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.6
# Epoch:[22]-Iteration:[100], training loss: 0.202
# Epoch:[22]-Iteration:[200], training loss: 0.195
# Time cost of one epoch: [89]s
# Epoch:[22], training accuracy: 94.2, training loss: 0.191
# Accuracy of the network on test images: 93.56
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 94.4
# Test Accuracy of 2: 94.6
# Test Accuracy of 3: 89.6
# Test Accuracy of 4: 96.4
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 93.8
# Epoch:[23]-Iteration:[100], training loss: 0.186
# Epoch:[23]-Iteration:[200], training loss: 0.193
# Time cost of one epoch: [89]s
# Epoch:[23], training accuracy: 94.2, training loss: 0.193
# Accuracy of the network on test images: 93.44
# Test Accuracy of 0: 93.0
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 95.2
# Test Accuracy of 3: 90.6
# Test Accuracy of 4: 96.2
# Test Accuracy of 5: 91.4
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 93.4
# Epoch:[24]-Iteration:[100], training loss: 0.190
# Epoch:[24]-Iteration:[200], training loss: 0.188
# Time cost of one epoch: [89]s
# Epoch:[24], training accuracy: 94.3, training loss: 0.189
# Accuracy of the network on test images: 93.54
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 95.0
# Test Accuracy of 3: 90.6
# Test Accuracy of 4: 96.2
# Test Accuracy of 5: 92.0
# Test Accuracy of 6: 93.0
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 93.2
# Test Accuracy of 9: 93.4
# Epoch:[25]-Iteration:[100], training loss: 0.187
# Epoch:[25]-Iteration:[200], training loss: 0.186
# Time cost of one epoch: [90]s
# Epoch:[25], training accuracy: 94.3, training loss: 0.187
# Accuracy of the network on test images: 93.46
# Test Accuracy of 0: 93.2
# Test Accuracy of 1: 92.8
# Test Accuracy of 2: 95.6
# Test Accuracy of 3: 89.4
# Test Accuracy of 4: 96.0
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.2
# Epoch:[26]-Iteration:[100], training loss: 0.178
# Epoch:[26]-Iteration:[200], training loss: 0.183
# Time cost of one epoch: [90]s
# Epoch:[26], training accuracy: 94.5, training loss: 0.182
# Accuracy of the network on test images: 93.46
# Test Accuracy of 0: 92.8
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 95.2
# Test Accuracy of 3: 90.0
# Test Accuracy of 4: 96.0
# Test Accuracy of 5: 92.0
# Test Accuracy of 6: 93.2
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 92.4
# Test Accuracy of 9: 93.8
# Epoch:[27]-Iteration:[100], training loss: 0.186
# Epoch:[27]-Iteration:[200], training loss: 0.184
# Time cost of one epoch: [89]s
# Epoch:[27], training accuracy: 94.5, training loss: 0.185
# Accuracy of the network on test images: 93.52
# Test Accuracy of 0: 93.8
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 89.8
# Test Accuracy of 4: 96.2
# Test Accuracy of 5: 92.0
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 92.8
# Epoch:[28]-Iteration:[100], training loss: 0.187
# Epoch:[28]-Iteration:[200], training loss: 0.184
# Time cost of one epoch: [89]s
# Epoch:[28], training accuracy: 94.4, training loss: 0.185
# Accuracy of the network on test images: 93.66
# Test Accuracy of 0: 94.2
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 95.2
# Test Accuracy of 3: 91.4
# Test Accuracy of 4: 95.6
# Test Accuracy of 5: 91.6
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 92.8
# Epoch:[29]-Iteration:[100], training loss: 0.190
# Epoch:[29]-Iteration:[200], training loss: 0.186
# Time cost of one epoch: [89]s
# Epoch:[29], training accuracy: 94.4, training loss: 0.184
# Accuracy of the network on test images: 93.68
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 95.0
# Test Accuracy of 3: 90.6
# Test Accuracy of 4: 96.4
# Test Accuracy of 5: 91.8
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 94.0
# Test Accuracy of 9: 92.8
# Epoch:[30]-Iteration:[100], training loss: 0.174
# Epoch:[30]-Iteration:[200], training loss: 0.178
# Time cost of one epoch: [89]s
# Epoch:[30], training accuracy: 94.6, training loss: 0.180
# Accuracy of the network on test images: 93.66
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.6
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.0
# Epoch:[31]-Iteration:[100], training loss: 0.177
# Epoch:[31]-Iteration:[200], training loss: 0.176
# Time cost of one epoch: [89]s
# Epoch:[31], training accuracy: 94.5, training loss: 0.177
# Accuracy of the network on test images: 93.64
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.6
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.6
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.0
# Epoch:[32]-Iteration:[100], training loss: 0.178
# Epoch:[32]-Iteration:[200], training loss: 0.180
# Time cost of one epoch: [89]s
# Epoch:[32], training accuracy: 94.5, training loss: 0.179
# Accuracy of the network on test images: 93.68
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.6
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 91.0
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.2
# Epoch:[33]-Iteration:[100], training loss: 0.175
# Epoch:[33]-Iteration:[200], training loss: 0.175
# Time cost of one epoch: [89]s
# Epoch:[33], training accuracy: 94.7, training loss: 0.173
# Accuracy of the network on test images: 93.7
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.6
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 91.0
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.4
# Epoch:[34]-Iteration:[100], training loss: 0.181
# Epoch:[34]-Iteration:[200], training loss: 0.178
# Time cost of one epoch: [89]s
# Epoch:[34], training accuracy: 94.5, training loss: 0.179
# Accuracy of the network on test images: 93.68
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.2
# Epoch:[35]-Iteration:[100], training loss: 0.182
# Epoch:[35]-Iteration:[200], training loss: 0.177
# Time cost of one epoch: [88]s
# Epoch:[35], training accuracy: 94.7, training loss: 0.173
# Accuracy of the network on test images: 93.7
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.6
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.4
# Epoch:[36]-Iteration:[100], training loss: 0.180
# Epoch:[36]-Iteration:[200], training loss: 0.177
# Time cost of one epoch: [88]s
# Epoch:[36], training accuracy: 94.7, training loss: 0.178
# Accuracy of the network on test images: 93.7
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.6
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.4
# Epoch:[37]-Iteration:[100], training loss: 0.183
# Epoch:[37]-Iteration:[200], training loss: 0.176
# Time cost of one epoch: [90]s
# Epoch:[37], training accuracy: 94.8, training loss: 0.176
# Accuracy of the network on test images: 93.74
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 94.0
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.4
# Epoch:[38]-Iteration:[100], training loss: 0.174
# Epoch:[38]-Iteration:[200], training loss: 0.178
# Time cost of one epoch: [89]s
# Epoch:[38], training accuracy: 94.6, training loss: 0.178
# Accuracy of the network on test images: 93.74
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.4
# Epoch:[39]-Iteration:[100], training loss: 0.173
# Epoch:[39]-Iteration:[200], training loss: 0.180
# Time cost of one epoch: [89]s
# Epoch:[39], training accuracy: 94.5, training loss: 0.178
# Accuracy of the network on test images: 93.74
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 94.0
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.4
# Epoch:[40]-Iteration:[100], training loss: 0.179
# Epoch:[40]-Iteration:[200], training loss: 0.176
# Time cost of one epoch: [88]s
# Epoch:[40], training accuracy: 94.6, training loss: 0.175
# Accuracy of the network on test images: 93.72
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 94.2
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.4
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.4
# Epoch:[41]-Iteration:[100], training loss: 0.186
# Epoch:[41]-Iteration:[200], training loss: 0.176
# Time cost of one epoch: [88]s
# Epoch:[41], training accuracy: 94.6, training loss: 0.178
# Accuracy of the network on test images: 93.74
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 94.0
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.4
# Epoch:[42]-Iteration:[100], training loss: 0.172
# Epoch:[42]-Iteration:[200], training loss: 0.177
# Time cost of one epoch: [88]s
# Epoch:[42], training accuracy: 94.5, training loss: 0.181
# Accuracy of the network on test images: 93.72
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 94.0
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 93.4
# Epoch:[43]-Iteration:[100], training loss: 0.175
# Epoch:[43]-Iteration:[200], training loss: 0.177
# Time cost of one epoch: [87]s
# Epoch:[43], training accuracy: 94.6, training loss: 0.177
# Accuracy of the network on test images: 93.78
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 94.2
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 93.0
# Test Accuracy of 9: 93.4
# Epoch:[44]-Iteration:[100], training loss: 0.167
# Epoch:[44]-Iteration:[200], training loss: 0.177
# Time cost of one epoch: [89]s
# Epoch:[44], training accuracy: 94.6, training loss: 0.175
# Accuracy of the network on test images: 93.8
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 94.2
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 93.0
# Test Accuracy of 9: 93.4
# Epoch:[45]-Iteration:[100], training loss: 0.177
# Epoch:[45]-Iteration:[200], training loss: 0.178
# Time cost of one epoch: [89]s
# Epoch:[45], training accuracy: 94.5, training loss: 0.179
# Accuracy of the network on test images: 93.78
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 94.2
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.4
# Epoch:[46]-Iteration:[100], training loss: 0.171
# Epoch:[46]-Iteration:[200], training loss: 0.173
# Time cost of one epoch: [89]s
# Epoch:[46], training accuracy: 94.8, training loss: 0.175
# Accuracy of the network on test images: 93.78
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 94.2
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.4
# Epoch:[47]-Iteration:[100], training loss: 0.175
# Epoch:[47]-Iteration:[200], training loss: 0.174
# Time cost of one epoch: [89]s
# Epoch:[47], training accuracy: 94.7, training loss: 0.173
# Accuracy of the network on test images: 93.78
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 94.2
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.4
# Epoch:[48]-Iteration:[100], training loss: 0.178
# Epoch:[48]-Iteration:[200], training loss: 0.175
# Time cost of one epoch: [89]s
# Epoch:[48], training accuracy: 94.5, training loss: 0.176
# Accuracy of the network on test images: 93.78
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 94.2
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.4
# Epoch:[49]-Iteration:[100], training loss: 0.169
# Epoch:[49]-Iteration:[200], training loss: 0.170
# Time cost of one epoch: [88]s
# Epoch:[49], training accuracy: 94.9, training loss: 0.171
# Accuracy of the network on test images: 93.78
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 94.2
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.4
# Epoch:[50]-Iteration:[100], training loss: 0.178
# Epoch:[50]-Iteration:[200], training loss: 0.173
# Time cost of one epoch: [88]s
# Epoch:[50], training accuracy: 94.7, training loss: 0.174
# Accuracy of the network on test images: 93.78
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 94.2
# Test Accuracy of 2: 95.4
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 93.4
# Finished Training
# time required 4723.57s

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(list(range(1,epoch+1)), history["train_accuracy"], label="Train")
plt.plot(list(range(1,epoch+1)), history["val_accuracy"], label="Test")
plt.xlabel("Epoch")
ax = plt.gca()
ax.set_ylim([90, 95])
plt.ylabel("Accuracy")
plt.legend()
plt.show()
print("Epoch with max test accuracy:", history["val_accuracy"].index(min(history["val_accuracy"]))+1)
# Out:
# Epoch with max test accuracy: 1
