# %%
from __future__ import print_function, division

import torch
import torch.optim as optim

from torch.optim import lr_scheduler
from torchvision import datasets, transforms
import time
import os

import torch.nn as nn

# TODO: You can modify the network architecture
class Net(nn.Module):
    """
    Input - 1x32x32
    Output - 10
    """
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=7, padding=3, stride=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(p=0.3),

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(p=0.3),

            nn.Flatten(), 
            nn.Linear(256*4*4, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
            )
        
    def forward(self, xb):
        return self.network(xb)

# %%
from random import randrange
# TODO: You can try different augmentation strategies
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomChoice([transforms.Pad(padding=4, fill=(randrange(256),randrange(256),randrange(256))), transforms.ElasticTransform(),transforms.GaussianBlur((3,3))]),
        transforms.RandomGrayscale(0.15),
        transforms.RandomAffine(degrees=10, translate=(0,0.1)),
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),

    ]),
    'test': transforms.Compose([
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

# %%
data_dir = '/kaggle/input/dtc314/data' # Suppose the dataset is stored under this folder
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'test']} # Read train and test sets, respectively.

train_dataloader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=128,
                                             shuffle=True, num_workers=4)

test_dataloader = torch.utils.data.DataLoader(image_datasets['test'], batch_size=128,
                                             shuffle=False, num_workers=4)

train_size =len(image_datasets['train'])


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # Set device to "cpu" if you have no gpu

# %%
history = dict()

def train_test(model, criterion, optimizer, scheduler, num_epochs=25):
    train_loss = []
    train_accuracy = []
    val_loss = [] 
    val_accuracy = []
    model.train()
    for epoch in range(num_epochs):
        running_training_loss = 0.0
        running_training_accuracy = 0.0
        iteration_training_loss = 0.0
        total_training_predictions = 0
       
        start_time = time.time()
        for i, data in enumerate(train_dataloader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_training_loss += loss.item()*inputs.size(0)
            
            _, predicted = torch.max(outputs.data, 1)
            total_training_predictions += labels.size(0)
            running_training_accuracy += (predicted == labels).sum().item()
            iteration_training_loss += loss.item() 
            if (i+1) % 100 == 0:
                print('Epoch:[%d]-Iteration:[%d], training loss: %.3f' %
                      (epoch + 1,i+1,iteration_training_loss/(i+1)))
        end_time = time.time()
        print('Time cost of one epoch: [%d]s' % (end_time-start_time))
        
        epoch_training_accuracy = running_training_accuracy / train_size*100
        epoch_training_loss = running_training_loss / train_size
        
        print('Epoch:[%d], training accuracy: %.1f, training loss: %.3f' %
              (epoch + 1,epoch_training_accuracy, epoch_training_loss))
        
        train_loss.append(epoch_training_loss)
        train_accuracy.append(epoch_training_accuracy)
        
        correct = 0
        total = 0
        labelsCorrect = [0 for i in range(10)]
        labelsTotal = [0 for i in range(10)]
        model.eval()
        # Since we're not training, we don't need to calculate the gradients for our outputs
        with torch.no_grad():
            for data in test_dataloader:
                images, labels = data[0].to(device), data[1].to(device)
                # calculate outputs by running images through the network
                outputs = model(images)
                # the class with the highest energy is what we choose as prediction
                _, predicted = torch.max(outputs.data, 1)
                tmp = (predicted == labels)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                for i in range(labels.size(0)): 
                    label = labels.data[i]
                    labelsCorrect[label] += tmp[i]
                    labelsTotal[label] += 1
        accuracy = float(100) * correct / total
        print(f'Accuracy of the network on test images: {accuracy}')
        for i in range(10): 
            acc = (labelsCorrect[i]/labelsTotal[i]).item
            print(f"Test Accuracy of {i}: {round((labelsCorrect[i]/labelsTotal[i]).item()*100,2)}")        
        val_accuracy.append(accuracy)
        scheduler.step()
        
    print('Finished Training')

    history['train_loss'] = train_loss
    history['train_accuracy'] = train_accuracy
    history['val_accuracy'] = val_accuracy

    return history, accuracy

# %%
epoch = 50

if __name__ == '__main__':
    end = time.time()
    model_ft = Net().to(device) # Model initialization
    print(model_ft.network)
    criterion = nn.CrossEntropyLoss() # Loss function initialization

    # TODO: Adjust the following hyper-parameters: initial learning rate, decay strategy of the learning rate, 
    #       number of training epochs
    optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.001) # The initial learning rate is 1e-3

    exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=20, gamma=0.05) 
    
    history, accuracy = train_test(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
               num_epochs=epoch)
    
    print("time required %.2fs" %(time.time() - end))
# Out:
# Sequential(
#   (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (1): ReLU()
#   (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU()
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Dropout(p=0.3, inplace=False)
#   (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU()
#   (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU()
#   (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (11): Dropout(p=0.3, inplace=False)
#   (12): Flatten(start_dim=1, end_dim=-1)
#   (13): Linear(in_features=4096, out_features=128, bias=True)
#   (14): ReLU()
#   (15): Linear(in_features=128, out_features=10, bias=True)
# )
# Epoch:[1]-Iteration:[100], training loss: 2.304
# Epoch:[1]-Iteration:[200], training loss: 2.233
# Time cost of one epoch: [88]s
# Epoch:[1], training accuracy: 18.7, training loss: 2.153
# Accuracy of the network on test images: 56.74
# Test Accuracy of 0: 77.6
# Test Accuracy of 1: 62.8
# Test Accuracy of 2: 61.8
# Test Accuracy of 3: 34.0
# Test Accuracy of 4: 67.2
# Test Accuracy of 5: 67.8
# Test Accuracy of 6: 36.4
# Test Accuracy of 7: 69.8
# Test Accuracy of 8: 54.2
# Test Accuracy of 9: 35.8
# Epoch:[2]-Iteration:[100], training loss: 1.121
# Epoch:[2]-Iteration:[200], training loss: 0.968
# Time cost of one epoch: [87]s
# Epoch:[2], training accuracy: 69.9, training loss: 0.933
# Accuracy of the network on test images: 84.16
# Test Accuracy of 0: 89.6
# Test Accuracy of 1: 87.2
# Test Accuracy of 2: 88.8
# Test Accuracy of 3: 79.2
# Test Accuracy of 4: 91.8
# Test Accuracy of 5: 74.0
# Test Accuracy of 6: 78.0
# Test Accuracy of 7: 89.2
# Test Accuracy of 8: 83.6
# Test Accuracy of 9: 80.2
# Epoch:[3]-Iteration:[100], training loss: 0.645
# Epoch:[3]-Iteration:[200], training loss: 0.615
# Time cost of one epoch: [87]s
# Epoch:[3], training accuracy: 80.8, training loss: 0.607
# Accuracy of the network on test images: 88.02
# Test Accuracy of 0: 91.8
# Test Accuracy of 1: 91.2
# Test Accuracy of 2: 90.8
# Test Accuracy of 3: 81.0
# Test Accuracy of 4: 89.6
# Test Accuracy of 5: 90.2
# Test Accuracy of 6: 87.2
# Test Accuracy of 7: 89.4
# Test Accuracy of 8: 82.8
# Test Accuracy of 9: 86.2
# Epoch:[4]-Iteration:[100], training loss: 0.530
# Epoch:[4]-Iteration:[200], training loss: 0.513
# Time cost of one epoch: [89]s
# Epoch:[4], training accuracy: 84.1, training loss: 0.507
# Accuracy of the network on test images: 88.9
# Test Accuracy of 0: 93.8
# Test Accuracy of 1: 88.4
# Test Accuracy of 2: 89.0
# Test Accuracy of 3: 80.8
# Test Accuracy of 4: 92.0
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 93.0
# Test Accuracy of 7: 96.0
# Test Accuracy of 8: 77.4
# Test Accuracy of 9: 88.2
# Epoch:[5]-Iteration:[100], training loss: 0.462
# Epoch:[5]-Iteration:[200], training loss: 0.452
# Time cost of one epoch: [89]s
# Epoch:[5], training accuracy: 86.1, training loss: 0.450
# Accuracy of the network on test images: 89.5
# Test Accuracy of 0: 95.0
# Test Accuracy of 1: 89.4
# Test Accuracy of 2: 89.0
# Test Accuracy of 3: 87.8
# Test Accuracy of 4: 91.8
# Test Accuracy of 5: 85.6
# Test Accuracy of 6: 92.0
# Test Accuracy of 7: 92.8
# Test Accuracy of 8: 79.8
# Test Accuracy of 9: 91.8
# Epoch:[6]-Iteration:[100], training loss: 0.403
# Epoch:[6]-Iteration:[200], training loss: 0.411
# Time cost of one epoch: [89]s
# Epoch:[6], training accuracy: 87.3, training loss: 0.413
# Accuracy of the network on test images: 90.68
# Test Accuracy of 0: 91.2
# Test Accuracy of 1: 91.4
# Test Accuracy of 2: 91.6
# Test Accuracy of 3: 86.8
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 88.8
# Test Accuracy of 6: 92.2
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 85.6
# Test Accuracy of 9: 89.8
# Epoch:[7]-Iteration:[100], training loss: 0.377
# Epoch:[7]-Iteration:[200], training loss: 0.377
# Time cost of one epoch: [90]s
# Epoch:[7], training accuracy: 88.4, training loss: 0.377
# Accuracy of the network on test images: 91.52
# Test Accuracy of 0: 93.2
# Test Accuracy of 1: 87.6
# Test Accuracy of 2: 92.2
# Test Accuracy of 3: 89.6
# Test Accuracy of 4: 95.0
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 92.4
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 88.0
# Test Accuracy of 9: 91.2
# Epoch:[8]-Iteration:[100], training loss: 0.361
# Epoch:[8]-Iteration:[200], training loss: 0.366
# Time cost of one epoch: [89]s
# Epoch:[8], training accuracy: 88.8, training loss: 0.364
# Accuracy of the network on test images: 90.86
# Test Accuracy of 0: 90.6
# Test Accuracy of 1: 92.8
# Test Accuracy of 2: 89.6
# Test Accuracy of 3: 87.8
# Test Accuracy of 4: 90.6
# Test Accuracy of 5: 90.0
# Test Accuracy of 6: 92.2
# Test Accuracy of 7: 93.0
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 89.8
# Epoch:[9]-Iteration:[100], training loss: 0.336
# Epoch:[9]-Iteration:[200], training loss: 0.341
# Time cost of one epoch: [88]s
# Epoch:[9], training accuracy: 89.4, training loss: 0.343
# Accuracy of the network on test images: 92.0
# Test Accuracy of 0: 95.4
# Test Accuracy of 1: 92.6
# Test Accuracy of 2: 92.2
# Test Accuracy of 3: 86.0
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 87.8
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 94.2
# Test Accuracy of 8: 88.8
# Test Accuracy of 9: 93.8
# Epoch:[10]-Iteration:[100], training loss: 0.315
# Epoch:[10]-Iteration:[200], training loss: 0.324
# Time cost of one epoch: [89]s
# Epoch:[10], training accuracy: 89.8, training loss: 0.327
# Accuracy of the network on test images: 91.52
# Test Accuracy of 0: 90.0
# Test Accuracy of 1: 87.4
# Test Accuracy of 2: 93.2
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 95.0
# Test Accuracy of 5: 92.0
# Test Accuracy of 6: 92.0
# Test Accuracy of 7: 93.0
# Test Accuracy of 8: 91.4
# Test Accuracy of 9: 90.4
# Epoch:[11]-Iteration:[100], training loss: 0.289
# Epoch:[11]-Iteration:[200], training loss: 0.311
# Time cost of one epoch: [89]s
# Epoch:[11], training accuracy: 90.6, training loss: 0.309
# Accuracy of the network on test images: 91.92
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 92.6
# Test Accuracy of 2: 92.8
# Test Accuracy of 3: 88.4
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 88.6
# Test Accuracy of 6: 93.2
# Test Accuracy of 7: 94.2
# Test Accuracy of 8: 89.8
# Test Accuracy of 9: 91.4
# Epoch:[12]-Iteration:[100], training loss: 0.285
# Epoch:[12]-Iteration:[200], training loss: 0.294
# Time cost of one epoch: [89]s
# Epoch:[12], training accuracy: 90.7, training loss: 0.301
# Accuracy of the network on test images: 92.34
# Test Accuracy of 0: 92.8
# Test Accuracy of 1: 91.8
# Test Accuracy of 2: 91.4
# Test Accuracy of 3: 90.6
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 92.8
# Test Accuracy of 7: 94.4
# Test Accuracy of 8: 89.6
# Test Accuracy of 9: 94.4
# Epoch:[13]-Iteration:[100], training loss: 0.281
# Epoch:[13]-Iteration:[200], training loss: 0.289
# Time cost of one epoch: [89]s
# Epoch:[13], training accuracy: 91.1, training loss: 0.292
# Accuracy of the network on test images: 92.28
# Test Accuracy of 0: 91.2
# Test Accuracy of 1: 92.8
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 92.0
# Test Accuracy of 5: 92.8
# Test Accuracy of 6: 94.0
# Test Accuracy of 7: 94.0
# Test Accuracy of 8: 91.2
# Test Accuracy of 9: 90.4
# Epoch:[14]-Iteration:[100], training loss: 0.286
# Epoch:[14]-Iteration:[200], training loss: 0.286
# Time cost of one epoch: [88]s
# Epoch:[14], training accuracy: 91.2, training loss: 0.284
# Accuracy of the network on test images: 91.58
# Test Accuracy of 0: 92.0
# Test Accuracy of 1: 89.2
# Test Accuracy of 2: 90.8
# Test Accuracy of 3: 90.2
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 87.2
# Test Accuracy of 6: 94.4
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 89.4
# Test Accuracy of 9: 91.8
# Epoch:[15]-Iteration:[100], training loss: 0.269
# Epoch:[15]-Iteration:[200], training loss: 0.278
# Time cost of one epoch: [88]s
# Epoch:[15], training accuracy: 91.5, training loss: 0.276
# Accuracy of the network on test images: 92.08
# Test Accuracy of 0: 90.0
# Test Accuracy of 1: 92.6
# Test Accuracy of 2: 93.2
# Test Accuracy of 3: 86.4
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 93.2
# Test Accuracy of 7: 94.4
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 91.6
# Epoch:[16]-Iteration:[100], training loss: 0.268
# Epoch:[16]-Iteration:[200], training loss: 0.265
# Time cost of one epoch: [88]s
# Epoch:[16], training accuracy: 91.8, training loss: 0.266
# Accuracy of the network on test images: 92.4
# Test Accuracy of 0: 91.8
# Test Accuracy of 1: 94.6
# Test Accuracy of 2: 92.4
# Test Accuracy of 3: 88.2
# Test Accuracy of 4: 96.0
# Test Accuracy of 5: 90.6
# Test Accuracy of 6: 91.8
# Test Accuracy of 7: 96.4
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 90.6
# Epoch:[17]-Iteration:[100], training loss: 0.250
# Epoch:[17]-Iteration:[200], training loss: 0.258
# Time cost of one epoch: [88]s
# Epoch:[17], training accuracy: 91.8, training loss: 0.262
# Accuracy of the network on test images: 91.96
# Test Accuracy of 0: 92.6
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 88.8
# Test Accuracy of 3: 92.4
# Test Accuracy of 4: 93.8
# Test Accuracy of 5: 87.2
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 90.2
# Test Accuracy of 9: 92.0
# Epoch:[18]-Iteration:[100], training loss: 0.244
# Epoch:[18]-Iteration:[200], training loss: 0.251
# Time cost of one epoch: [89]s
# Epoch:[18], training accuracy: 92.1, training loss: 0.253
# Accuracy of the network on test images: 92.04
# Test Accuracy of 0: 92.6
# Test Accuracy of 1: 90.8
# Test Accuracy of 2: 90.8
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 91.0
# Test Accuracy of 6: 91.4
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 90.8
# Test Accuracy of 9: 90.8
# Epoch:[19]-Iteration:[100], training loss: 0.242
# Epoch:[19]-Iteration:[200], training loss: 0.243
# Time cost of one epoch: [88]s
# Epoch:[19], training accuracy: 92.3, training loss: 0.246
# Accuracy of the network on test images: 92.0
# Test Accuracy of 0: 91.6
# Test Accuracy of 1: 92.4
# Test Accuracy of 2: 92.6
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.8
# Test Accuracy of 5: 87.2
# Test Accuracy of 6: 91.4
# Test Accuracy of 7: 94.4
# Test Accuracy of 8: 94.4
# Test Accuracy of 9: 88.6
# Epoch:[20]-Iteration:[100], training loss: 0.239
# Epoch:[20]-Iteration:[200], training loss: 0.238
# Time cost of one epoch: [88]s
# Epoch:[20], training accuracy: 92.6, training loss: 0.235
# Accuracy of the network on test images: 92.46
# Test Accuracy of 0: 92.6
# Test Accuracy of 1: 89.2
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 89.6
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 91.4
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 96.0
# Test Accuracy of 8: 91.0
# Test Accuracy of 9: 91.2
# Epoch:[21]-Iteration:[100], training loss: 0.208
# Epoch:[21]-Iteration:[200], training loss: 0.203
# Time cost of one epoch: [89]s
# Epoch:[21], training accuracy: 93.8, training loss: 0.200
# Accuracy of the network on test images: 93.24
# Test Accuracy of 0: 93.0
# Test Accuracy of 1: 93.0
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.8
# Test Accuracy of 5: 90.8
# Test Accuracy of 6: 94.4
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 92.8
# Epoch:[22]-Iteration:[100], training loss: 0.205
# Epoch:[22]-Iteration:[200], training loss: 0.195
# Time cost of one epoch: [90]s
# Epoch:[22], training accuracy: 94.1, training loss: 0.191
# Accuracy of the network on test images: 93.32
# Test Accuracy of 0: 93.8
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 93.0
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.6
# Test Accuracy of 5: 91.8
# Test Accuracy of 6: 94.6
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 92.0
# Test Accuracy of 9: 91.8
# Epoch:[23]-Iteration:[100], training loss: 0.181
# Epoch:[23]-Iteration:[200], training loss: 0.182
# Time cost of one epoch: [90]s
# Epoch:[23], training accuracy: 94.3, training loss: 0.182
# Accuracy of the network on test images: 93.48
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 91.8
# Test Accuracy of 4: 95.8
# Test Accuracy of 5: 91.4
# Test Accuracy of 6: 95.4
# Test Accuracy of 7: 96.2
# Test Accuracy of 8: 91.8
# Test Accuracy of 9: 92.4
# Epoch:[24]-Iteration:[100], training loss: 0.175
# Epoch:[24]-Iteration:[200], training loss: 0.170
# Time cost of one epoch: [89]s
# Epoch:[24], training accuracy: 94.7, training loss: 0.174
# Accuracy of the network on test images: 93.54
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 93.8
# Test Accuracy of 3: 91.8
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 95.4
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 92.6
# Epoch:[25]-Iteration:[100], training loss: 0.173
# Epoch:[25]-Iteration:[200], training loss: 0.173
# Time cost of one epoch: [89]s
# Epoch:[25], training accuracy: 94.9, training loss: 0.173
# Accuracy of the network on test images: 93.54
# Test Accuracy of 0: 94.0
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 93.0
# Test Accuracy of 3: 91.8
# Test Accuracy of 4: 96.0
# Test Accuracy of 5: 92.0
# Test Accuracy of 6: 95.0
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 91.8
# Test Accuracy of 9: 92.6
# Epoch:[26]-Iteration:[100], training loss: 0.176
# Epoch:[26]-Iteration:[200], training loss: 0.172
# Time cost of one epoch: [89]s
# Epoch:[26], training accuracy: 94.6, training loss: 0.173
# Accuracy of the network on test images: 93.48
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 93.2
# Test Accuracy of 3: 91.2
# Test Accuracy of 4: 95.6
# Test Accuracy of 5: 92.0
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 92.6
# Epoch:[27]-Iteration:[100], training loss: 0.170
# Epoch:[27]-Iteration:[200], training loss: 0.172
# Time cost of one epoch: [89]s
# Epoch:[27], training accuracy: 94.8, training loss: 0.172
# Accuracy of the network on test images: 93.64
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.6
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 92.0
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 95.8
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.4
# Test Accuracy of 9: 92.8
# Epoch:[28]-Iteration:[100], training loss: 0.172
# Epoch:[28]-Iteration:[200], training loss: 0.165
# Time cost of one epoch: [89]s
# Epoch:[28], training accuracy: 94.8, training loss: 0.166
# Accuracy of the network on test images: 93.52
# Test Accuracy of 0: 93.8
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 93.2
# Test Accuracy of 3: 92.2
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 91.6
# Test Accuracy of 6: 95.0
# Test Accuracy of 7: 96.2
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 92.6
# Epoch:[29]-Iteration:[100], training loss: 0.171
# Epoch:[29]-Iteration:[200], training loss: 0.164
# Time cost of one epoch: [89]s
# Epoch:[29], training accuracy: 95.0, training loss: 0.165
# Accuracy of the network on test images: 93.54
# Test Accuracy of 0: 93.0
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 93.8
# Test Accuracy of 3: 92.0
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 95.4
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.4
# Test Accuracy of 9: 92.6
# Epoch:[30]-Iteration:[100], training loss: 0.169
# Epoch:[30]-Iteration:[200], training loss: 0.164
# Time cost of one epoch: [89]s
# Epoch:[30], training accuracy: 94.9, training loss: 0.164
# Accuracy of the network on test images: 93.66
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.6
# Test Accuracy of 2: 94.2
# Test Accuracy of 3: 91.4
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 93.0
# Test Accuracy of 6: 95.0
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 93.0
# Epoch:[31]-Iteration:[100], training loss: 0.163
# Epoch:[31]-Iteration:[200], training loss: 0.162
# Time cost of one epoch: [88]s
# Epoch:[31], training accuracy: 94.9, training loss: 0.161
# Accuracy of the network on test images: 93.6
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.6
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 92.2
# Test Accuracy of 4: 95.0
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 95.0
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 92.4
# Test Accuracy of 9: 92.6
# Epoch:[32]-Iteration:[100], training loss: 0.173
# Epoch:[32]-Iteration:[200], training loss: 0.164
# Time cost of one epoch: [89]s
# Epoch:[32], training accuracy: 95.0, training loss: 0.163
# Accuracy of the network on test images: 93.44
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.0
# Test Accuracy of 2: 94.2
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 92.6
# Test Accuracy of 6: 96.0
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 91.2
# Test Accuracy of 9: 92.2
# Epoch:[33]-Iteration:[100], training loss: 0.162
# Epoch:[33]-Iteration:[200], training loss: 0.159
# Time cost of one epoch: [89]s
# Epoch:[33], training accuracy: 95.0, training loss: 0.160
# Accuracy of the network on test images: 93.8
# Test Accuracy of 0: 93.8
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 94.0
# Test Accuracy of 3: 92.4
# Test Accuracy of 4: 95.6
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 95.6
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 92.6
# Epoch:[34]-Iteration:[100], training loss: 0.160
# Epoch:[34]-Iteration:[200], training loss: 0.160
# Time cost of one epoch: [88]s
# Epoch:[34], training accuracy: 95.0, training loss: 0.163
# Accuracy of the network on test images: 93.62
# Test Accuracy of 0: 94.2
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 94.2
# Test Accuracy of 3: 91.4
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 92.0
# Test Accuracy of 6: 95.6
# Test Accuracy of 7: 96.0
# Test Accuracy of 8: 91.8
# Test Accuracy of 9: 92.6
# Epoch:[35]-Iteration:[100], training loss: 0.153
# Epoch:[35]-Iteration:[200], training loss: 0.157
# Time cost of one epoch: [89]s
# Epoch:[35], training accuracy: 95.1, training loss: 0.159
# Accuracy of the network on test images: 93.58
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 93.8
# Test Accuracy of 3: 92.0
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 95.4
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 92.2
# Epoch:[36]-Iteration:[100], training loss: 0.156
# Epoch:[36]-Iteration:[200], training loss: 0.161
# Time cost of one epoch: [88]s
# Epoch:[36], training accuracy: 95.1, training loss: 0.158
# Accuracy of the network on test images: 93.5
# Test Accuracy of 0: 93.0
# Test Accuracy of 1: 93.6
# Test Accuracy of 2: 93.2
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.0
# Test Accuracy of 5: 93.2
# Test Accuracy of 6: 95.2
# Test Accuracy of 7: 96.2
# Test Accuracy of 8: 91.4
# Test Accuracy of 9: 92.6
# Epoch:[37]-Iteration:[100], training loss: 0.157
# Epoch:[37]-Iteration:[200], training loss: 0.157
# Time cost of one epoch: [88]s
# Epoch:[37], training accuracy: 95.2, training loss: 0.156
# Accuracy of the network on test images: 93.5
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 91.6
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 93.4
# Test Accuracy of 9: 92.2
# Epoch:[38]-Iteration:[100], training loss: 0.164
# Epoch:[38]-Iteration:[200], training loss: 0.158
# Time cost of one epoch: [89]s
# Epoch:[38], training accuracy: 95.1, training loss: 0.158
# Accuracy of the network on test images: 93.44
# Test Accuracy of 0: 93.0
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 93.8
# Test Accuracy of 3: 91.8
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 95.8
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 92.2
# Epoch:[39]-Iteration:[100], training loss: 0.148
# Epoch:[39]-Iteration:[200], training loss: 0.153
# Time cost of one epoch: [89]s
# Epoch:[39], training accuracy: 95.3, training loss: 0.153
# Accuracy of the network on test images: 93.44
# Test Accuracy of 0: 93.2
# Test Accuracy of 1: 92.8
# Test Accuracy of 2: 93.8
# Test Accuracy of 3: 92.0
# Test Accuracy of 4: 95.0
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 95.6
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 91.4
# Test Accuracy of 9: 92.4
# Epoch:[40]-Iteration:[100], training loss: 0.144
# Epoch:[40]-Iteration:[200], training loss: 0.151
# Time cost of one epoch: [89]s
# Epoch:[40], training accuracy: 95.3, training loss: 0.152
# Accuracy of the network on test images: 93.42
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 94.0
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 95.0
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 92.4
# Epoch:[41]-Iteration:[100], training loss: 0.151
# Epoch:[41]-Iteration:[200], training loss: 0.150
# Time cost of one epoch: [89]s
# Epoch:[41], training accuracy: 95.3, training loss: 0.151
# Accuracy of the network on test images: 93.5
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 93.0
# Test Accuracy of 2: 94.0
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 92.0
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 92.4
# Epoch:[42]-Iteration:[100], training loss: 0.152
# Epoch:[42]-Iteration:[200], training loss: 0.154
# Time cost of one epoch: [89]s
# Epoch:[42], training accuracy: 95.3, training loss: 0.152
# Accuracy of the network on test images: 93.54
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 94.0
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 92.4
# Epoch:[43]-Iteration:[100], training loss: 0.146
# Epoch:[43]-Iteration:[200], training loss: 0.146
# Time cost of one epoch: [89]s
# Epoch:[43], training accuracy: 95.5, training loss: 0.146
# Accuracy of the network on test images: 93.56
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 94.2
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 92.4
# Epoch:[44]-Iteration:[100], training loss: 0.153
# Epoch:[44]-Iteration:[200], training loss: 0.152
# Time cost of one epoch: [89]s
# Epoch:[44], training accuracy: 95.3, training loss: 0.152
# Accuracy of the network on test images: 93.56
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 94.2
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 92.4
# Epoch:[45]-Iteration:[100], training loss: 0.148
# Epoch:[45]-Iteration:[200], training loss: 0.148
# Time cost of one epoch: [89]s
# Epoch:[45], training accuracy: 95.4, training loss: 0.151
# Accuracy of the network on test images: 93.56
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 94.2
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 92.4
# Epoch:[46]-Iteration:[100], training loss: 0.146
# Epoch:[46]-Iteration:[200], training loss: 0.151
# Time cost of one epoch: [89]s
# Epoch:[46], training accuracy: 95.3, training loss: 0.151
# Accuracy of the network on test images: 93.56
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 93.8
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 93.0
# Test Accuracy of 9: 92.4
# Epoch:[47]-Iteration:[100], training loss: 0.151
# Epoch:[47]-Iteration:[200], training loss: 0.148
# Time cost of one epoch: [88]s
# Epoch:[47], training accuracy: 95.6, training loss: 0.147
# Accuracy of the network on test images: 93.56
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 94.0
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 93.0
# Test Accuracy of 9: 92.4
# Epoch:[48]-Iteration:[100], training loss: 0.146
# Epoch:[48]-Iteration:[200], training loss: 0.148
# Time cost of one epoch: [89]s
# Epoch:[48], training accuracy: 95.4, training loss: 0.148
# Accuracy of the network on test images: 93.54
# Test Accuracy of 0: 93.2
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 93.8
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.0
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 95.0
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 93.0
# Test Accuracy of 9: 92.4
# Epoch:[49]-Iteration:[100], training loss: 0.151
# Epoch:[49]-Iteration:[200], training loss: 0.152
# Time cost of one epoch: [88]s
# Epoch:[49], training accuracy: 95.4, training loss: 0.150
# Accuracy of the network on test images: 93.56
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.0
# Test Accuracy of 2: 94.0
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 95.0
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 92.4
# Epoch:[50]-Iteration:[100], training loss: 0.148
# Epoch:[50]-Iteration:[200], training loss: 0.148
# Time cost of one epoch: [88]s
# Epoch:[50], training accuracy: 95.5, training loss: 0.147
# Accuracy of the network on test images: 93.54
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 93.8
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 92.6
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 92.4
# Finished Training
# time required 4710.77s

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(list(range(1,epoch+1)), history["train_accuracy"], label="Train")
plt.plot(list(range(1,epoch+1)), history["val_accuracy"], label="Test")
plt.xlabel("Epoch")
ax = plt.gca()
ax.set_ylim([90, 95])
plt.ylabel("Accuracy")
plt.legend()
plt.show()
print("Epoch with max test accuracy:", history["val_accuracy"].index(min(history["val_accuracy"]))+1)
# Out:
# Epoch with max test accuracy: 1
