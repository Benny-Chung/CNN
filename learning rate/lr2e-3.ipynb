# %%
from __future__ import print_function, division

import torch
import torch.optim as optim

from torch.optim import lr_scheduler
from torchvision import datasets, transforms
import time
import os

import torch.nn as nn

# TODO: You can modify the network architecture
class Net(nn.Module):
    """
    Input - 1x32x32
    Output - 10
    """
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=7, padding=3, stride=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(p=0.3),

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(p=0.3),

            nn.Flatten(), 
            nn.Linear(256*4*4, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
            )
        
    def forward(self, xb):
        return self.network(xb)

# %%
from random import randrange
# TODO: You can try different augmentation strategies
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomChoice([transforms.Pad(padding=4, fill=(randrange(256),randrange(256),randrange(256))), transforms.ElasticTransform(),transforms.GaussianBlur((3,3))]),
        transforms.RandomGrayscale(0.15),
        transforms.RandomAffine(degrees=10, translate=(0,0.1)),
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),

    ]),
    'test': transforms.Compose([
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

# %%
data_dir = '/kaggle/input/dtc314/data' # Suppose the dataset is stored under this folder
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'test']} # Read train and test sets, respectively.

train_dataloader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=128,
                                             shuffle=True, num_workers=4)

test_dataloader = torch.utils.data.DataLoader(image_datasets['test'], batch_size=128,
                                             shuffle=False, num_workers=4)

train_size =len(image_datasets['train'])


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # Set device to "cpu" if you have no gpu

# %%
history = dict()

def train_test(model, criterion, optimizer, scheduler, num_epochs=25):
    train_loss = []
    train_accuracy = []
    val_loss = [] 
    val_accuracy = []
    model.train()
    for epoch in range(num_epochs):
        running_training_loss = 0.0
        running_training_accuracy = 0.0
        iteration_training_loss = 0.0
        total_training_predictions = 0
       
        start_time = time.time()
        for i, data in enumerate(train_dataloader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_training_loss += loss.item()*inputs.size(0)
            
            _, predicted = torch.max(outputs.data, 1)
            total_training_predictions += labels.size(0)
            running_training_accuracy += (predicted == labels).sum().item()
            iteration_training_loss += loss.item() 
            if (i+1) % 100 == 0:
                print('Epoch:[%d]-Iteration:[%d], training loss: %.3f' %
                      (epoch + 1,i+1,iteration_training_loss/(i+1)))
        end_time = time.time()
        print('Time cost of one epoch: [%d]s' % (end_time-start_time))
        
        epoch_training_accuracy = running_training_accuracy / train_size*100
        epoch_training_loss = running_training_loss / train_size
        
        print('Epoch:[%d], training accuracy: %.1f, training loss: %.3f' %
              (epoch + 1,epoch_training_accuracy, epoch_training_loss))
        
        train_loss.append(epoch_training_loss)
        train_accuracy.append(epoch_training_accuracy)
        
        correct = 0
        total = 0
        labelsCorrect = [0 for i in range(10)]
        labelsTotal = [0 for i in range(10)]
        model.eval()
        # Since we're not training, we don't need to calculate the gradients for our outputs
        with torch.no_grad():
            for data in test_dataloader:
                images, labels = data[0].to(device), data[1].to(device)
                # calculate outputs by running images through the network
                outputs = model(images)
                # the class with the highest energy is what we choose as prediction
                _, predicted = torch.max(outputs.data, 1)
                tmp = (predicted == labels)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                for i in range(labels.size(0)): 
                    label = labels.data[i]
                    labelsCorrect[label] += tmp[i]
                    labelsTotal[label] += 1
        accuracy = float(100) * correct / total
        print(f'Accuracy of the network on test images: {accuracy}')
        for i in range(10): 
            acc = (labelsCorrect[i]/labelsTotal[i]).item
            print(f"Test Accuracy of {i}: {round((labelsCorrect[i]/labelsTotal[i]).item()*100,2)}")        
        val_accuracy.append(accuracy)
        scheduler.step()
        
    print('Finished Training')

    history['train_loss'] = train_loss
    history['train_accuracy'] = train_accuracy
    history['val_accuracy'] = val_accuracy

    return history, accuracy

# %%
epoch = 50

if __name__ == '__main__':
    end = time.time()
    model_ft = Net().to(device) # Model initialization
    print(model_ft.network)
    criterion = nn.CrossEntropyLoss() # Loss function initialization

    # TODO: Adjust the following hyper-parameters: initial learning rate, decay strategy of the learning rate, 
    #       number of training epochs
    optimizer_ft = optim.Adam(model_ft.parameters(), lr=0.002) # The initial learning rate is 1e-3

    exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=20, gamma=0.7) 
    
    history, accuracy = train_test(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
               num_epochs=epoch)
    
    print("time required %.2fs" %(time.time() - end))
# Out:
# Sequential(
#   (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (1): ReLU()
#   (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU()
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Dropout(p=0.3, inplace=False)
#   (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU()
#   (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU()
#   (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (11): Dropout(p=0.3, inplace=False)
#   (12): Flatten(start_dim=1, end_dim=-1)
#   (13): Linear(in_features=4096, out_features=128, bias=True)
#   (14): ReLU()
#   (15): Linear(in_features=128, out_features=10, bias=True)
# )
# Epoch:[1]-Iteration:[100], training loss: 2.304
# Epoch:[1]-Iteration:[200], training loss: 2.303
# Time cost of one epoch: [85]s
# Epoch:[1], training accuracy: 11.9, training loss: 2.284
# Accuracy of the network on test images: 34.98
# Test Accuracy of 0: 27.0
# Test Accuracy of 1: 83.8
# Test Accuracy of 2: 22.4
# Test Accuracy of 3: 37.4
# Test Accuracy of 4: 51.2
# Test Accuracy of 5: 12.4
# Test Accuracy of 6: 31.8
# Test Accuracy of 7: 31.8
# Test Accuracy of 8: 9.2
# Test Accuracy of 9: 42.8
# Epoch:[2]-Iteration:[100], training loss: 1.598
# Epoch:[2]-Iteration:[200], training loss: 1.425
# Time cost of one epoch: [84]s
# Epoch:[2], training accuracy: 52.3, training loss: 1.383
# Accuracy of the network on test images: 72.88
# Test Accuracy of 0: 78.6
# Test Accuracy of 1: 82.0
# Test Accuracy of 2: 82.2
# Test Accuracy of 3: 66.4
# Test Accuracy of 4: 80.4
# Test Accuracy of 5: 54.8
# Test Accuracy of 6: 72.2
# Test Accuracy of 7: 79.0
# Test Accuracy of 8: 68.0
# Test Accuracy of 9: 65.2
# Epoch:[3]-Iteration:[100], training loss: 0.973
# Epoch:[3]-Iteration:[200], training loss: 0.911
# Time cost of one epoch: [86]s
# Epoch:[3], training accuracy: 70.7, training loss: 0.895
# Accuracy of the network on test images: 81.2
# Test Accuracy of 0: 85.6
# Test Accuracy of 1: 72.8
# Test Accuracy of 2: 83.2
# Test Accuracy of 3: 80.8
# Test Accuracy of 4: 84.0
# Test Accuracy of 5: 81.4
# Test Accuracy of 6: 79.8
# Test Accuracy of 7: 87.8
# Test Accuracy of 8: 72.4
# Test Accuracy of 9: 84.2
# Epoch:[4]-Iteration:[100], training loss: 0.752
# Epoch:[4]-Iteration:[200], training loss: 0.720
# Time cost of one epoch: [88]s
# Epoch:[4], training accuracy: 76.5, training loss: 0.713
# Accuracy of the network on test images: 84.66
# Test Accuracy of 0: 84.0
# Test Accuracy of 1: 84.8
# Test Accuracy of 2: 87.6
# Test Accuracy of 3: 67.8
# Test Accuracy of 4: 91.6
# Test Accuracy of 5: 90.0
# Test Accuracy of 6: 81.8
# Test Accuracy of 7: 90.6
# Test Accuracy of 8: 82.2
# Test Accuracy of 9: 86.2
# Epoch:[5]-Iteration:[100], training loss: 0.650
# Epoch:[5]-Iteration:[200], training loss: 0.639
# Time cost of one epoch: [88]s
# Epoch:[5], training accuracy: 79.7, training loss: 0.636
# Accuracy of the network on test images: 85.84
# Test Accuracy of 0: 86.8
# Test Accuracy of 1: 91.0
# Test Accuracy of 2: 83.0
# Test Accuracy of 3: 74.8
# Test Accuracy of 4: 90.0
# Test Accuracy of 5: 84.0
# Test Accuracy of 6: 87.2
# Test Accuracy of 7: 90.2
# Test Accuracy of 8: 84.0
# Test Accuracy of 9: 87.4
# Epoch:[6]-Iteration:[100], training loss: 0.620
# Epoch:[6]-Iteration:[200], training loss: 0.599
# Time cost of one epoch: [88]s
# Epoch:[6], training accuracy: 81.0, training loss: 0.596
# Accuracy of the network on test images: 86.8
# Test Accuracy of 0: 88.0
# Test Accuracy of 1: 86.6
# Test Accuracy of 2: 88.6
# Test Accuracy of 3: 83.0
# Test Accuracy of 4: 92.6
# Test Accuracy of 5: 83.6
# Test Accuracy of 6: 85.0
# Test Accuracy of 7: 89.0
# Test Accuracy of 8: 84.2
# Test Accuracy of 9: 87.4
# Epoch:[7]-Iteration:[100], training loss: 0.579
# Epoch:[7]-Iteration:[200], training loss: 0.568
# Time cost of one epoch: [88]s
# Epoch:[7], training accuracy: 81.8, training loss: 0.565
# Accuracy of the network on test images: 87.2
# Test Accuracy of 0: 85.2
# Test Accuracy of 1: 83.6
# Test Accuracy of 2: 88.6
# Test Accuracy of 3: 88.2
# Test Accuracy of 4: 87.4
# Test Accuracy of 5: 87.8
# Test Accuracy of 6: 89.6
# Test Accuracy of 7: 89.6
# Test Accuracy of 8: 81.8
# Test Accuracy of 9: 90.2
# Epoch:[8]-Iteration:[100], training loss: 0.549
# Epoch:[8]-Iteration:[200], training loss: 0.541
# Time cost of one epoch: [88]s
# Epoch:[8], training accuracy: 82.7, training loss: 0.541
# Accuracy of the network on test images: 87.1
# Test Accuracy of 0: 85.0
# Test Accuracy of 1: 83.4
# Test Accuracy of 2: 87.4
# Test Accuracy of 3: 84.0
# Test Accuracy of 4: 93.4
# Test Accuracy of 5: 86.0
# Test Accuracy of 6: 81.4
# Test Accuracy of 7: 92.4
# Test Accuracy of 8: 90.8
# Test Accuracy of 9: 87.2
# Epoch:[9]-Iteration:[100], training loss: 0.526
# Epoch:[9]-Iteration:[200], training loss: 0.530
# Time cost of one epoch: [87]s
# Epoch:[9], training accuracy: 83.2, training loss: 0.533
# Accuracy of the network on test images: 87.7
# Test Accuracy of 0: 89.6
# Test Accuracy of 1: 85.4
# Test Accuracy of 2: 91.2
# Test Accuracy of 3: 90.2
# Test Accuracy of 4: 86.2
# Test Accuracy of 5: 79.6
# Test Accuracy of 6: 84.4
# Test Accuracy of 7: 89.6
# Test Accuracy of 8: 87.8
# Test Accuracy of 9: 93.0
# Epoch:[10]-Iteration:[100], training loss: 0.508
# Epoch:[10]-Iteration:[200], training loss: 0.515
# Time cost of one epoch: [87]s
# Epoch:[10], training accuracy: 83.7, training loss: 0.518
# Accuracy of the network on test images: 88.54
# Test Accuracy of 0: 89.0
# Test Accuracy of 1: 91.8
# Test Accuracy of 2: 90.4
# Test Accuracy of 3: 82.4
# Test Accuracy of 4: 91.0
# Test Accuracy of 5: 87.0
# Test Accuracy of 6: 90.6
# Test Accuracy of 7: 89.6
# Test Accuracy of 8: 85.0
# Test Accuracy of 9: 88.6
# Epoch:[11]-Iteration:[100], training loss: 0.483
# Epoch:[11]-Iteration:[200], training loss: 0.500
# Time cost of one epoch: [87]s
# Epoch:[11], training accuracy: 84.3, training loss: 0.500
# Accuracy of the network on test images: 88.24
# Test Accuracy of 0: 90.2
# Test Accuracy of 1: 89.8
# Test Accuracy of 2: 87.8
# Test Accuracy of 3: 80.2
# Test Accuracy of 4: 93.2
# Test Accuracy of 5: 86.6
# Test Accuracy of 6: 87.0
# Test Accuracy of 7: 89.8
# Test Accuracy of 8: 90.6
# Test Accuracy of 9: 87.2
# Epoch:[12]-Iteration:[100], training loss: 0.485
# Epoch:[12]-Iteration:[200], training loss: 0.484
# Time cost of one epoch: [88]s
# Epoch:[12], training accuracy: 84.8, training loss: 0.484
# Accuracy of the network on test images: 88.22
# Test Accuracy of 0: 88.6
# Test Accuracy of 1: 86.2
# Test Accuracy of 2: 88.6
# Test Accuracy of 3: 81.2
# Test Accuracy of 4: 91.4
# Test Accuracy of 5: 89.4
# Test Accuracy of 6: 89.2
# Test Accuracy of 7: 89.0
# Test Accuracy of 8: 86.6
# Test Accuracy of 9: 92.0
# Epoch:[13]-Iteration:[100], training loss: 0.474
# Epoch:[13]-Iteration:[200], training loss: 0.484
# Time cost of one epoch: [87]s
# Epoch:[13], training accuracy: 84.7, training loss: 0.483
# Accuracy of the network on test images: 88.92
# Test Accuracy of 0: 87.2
# Test Accuracy of 1: 86.0
# Test Accuracy of 2: 89.6
# Test Accuracy of 3: 89.6
# Test Accuracy of 4: 91.8
# Test Accuracy of 5: 82.2
# Test Accuracy of 6: 92.6
# Test Accuracy of 7: 93.4
# Test Accuracy of 8: 87.4
# Test Accuracy of 9: 89.4
# Epoch:[14]-Iteration:[100], training loss: 0.462
# Epoch:[14]-Iteration:[200], training loss: 0.471
# Time cost of one epoch: [87]s
# Epoch:[14], training accuracy: 85.0, training loss: 0.470
# Accuracy of the network on test images: 89.02
# Test Accuracy of 0: 89.0
# Test Accuracy of 1: 83.2
# Test Accuracy of 2: 91.2
# Test Accuracy of 3: 88.0
# Test Accuracy of 4: 93.8
# Test Accuracy of 5: 85.4
# Test Accuracy of 6: 87.4
# Test Accuracy of 7: 91.0
# Test Accuracy of 8: 88.6
# Test Accuracy of 9: 92.6
# Epoch:[15]-Iteration:[100], training loss: 0.459
# Epoch:[15]-Iteration:[200], training loss: 0.455
# Time cost of one epoch: [87]s
# Epoch:[15], training accuracy: 85.7, training loss: 0.456
# Accuracy of the network on test images: 88.86
# Test Accuracy of 0: 85.0
# Test Accuracy of 1: 83.0
# Test Accuracy of 2: 92.8
# Test Accuracy of 3: 86.6
# Test Accuracy of 4: 92.4
# Test Accuracy of 5: 88.4
# Test Accuracy of 6: 87.2
# Test Accuracy of 7: 91.4
# Test Accuracy of 8: 91.6
# Test Accuracy of 9: 90.2
# Epoch:[16]-Iteration:[100], training loss: 0.435
# Epoch:[16]-Iteration:[200], training loss: 0.447
# Time cost of one epoch: [87]s
# Epoch:[16], training accuracy: 86.0, training loss: 0.449
# Accuracy of the network on test images: 89.2
# Test Accuracy of 0: 91.0
# Test Accuracy of 1: 88.2
# Test Accuracy of 2: 92.2
# Test Accuracy of 3: 86.0
# Test Accuracy of 4: 94.2
# Test Accuracy of 5: 87.0
# Test Accuracy of 6: 89.2
# Test Accuracy of 7: 92.0
# Test Accuracy of 8: 82.4
# Test Accuracy of 9: 89.8
# Epoch:[17]-Iteration:[100], training loss: 0.448
# Epoch:[17]-Iteration:[200], training loss: 0.445
# Time cost of one epoch: [88]s
# Epoch:[17], training accuracy: 86.0, training loss: 0.446
# Accuracy of the network on test images: 89.56
# Test Accuracy of 0: 90.6
# Test Accuracy of 1: 88.8
# Test Accuracy of 2: 88.8
# Test Accuracy of 3: 86.8
# Test Accuracy of 4: 92.4
# Test Accuracy of 5: 88.2
# Test Accuracy of 6: 88.4
# Test Accuracy of 7: 93.2
# Test Accuracy of 8: 88.6
# Test Accuracy of 9: 89.8
# Epoch:[18]-Iteration:[100], training loss: 0.427
# Epoch:[18]-Iteration:[200], training loss: 0.434
# Time cost of one epoch: [87]s
# Epoch:[18], training accuracy: 86.5, training loss: 0.435
# Accuracy of the network on test images: 90.08
# Test Accuracy of 0: 91.2
# Test Accuracy of 1: 87.6
# Test Accuracy of 2: 91.2
# Test Accuracy of 3: 86.6
# Test Accuracy of 4: 94.0
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 88.2
# Test Accuracy of 7: 92.2
# Test Accuracy of 8: 87.8
# Test Accuracy of 9: 91.6
# Epoch:[19]-Iteration:[100], training loss: 0.437
# Epoch:[19]-Iteration:[200], training loss: 0.427
# Time cost of one epoch: [87]s
# Epoch:[19], training accuracy: 86.3, training loss: 0.433
# Accuracy of the network on test images: 89.52
# Test Accuracy of 0: 87.4
# Test Accuracy of 1: 92.4
# Test Accuracy of 2: 92.2
# Test Accuracy of 3: 84.2
# Test Accuracy of 4: 90.2
# Test Accuracy of 5: 91.2
# Test Accuracy of 6: 87.8
# Test Accuracy of 7: 92.0
# Test Accuracy of 8: 84.6
# Test Accuracy of 9: 93.2
# Epoch:[20]-Iteration:[100], training loss: 0.426
# Epoch:[20]-Iteration:[200], training loss: 0.432
# Time cost of one epoch: [87]s
# Epoch:[20], training accuracy: 86.5, training loss: 0.433
# Accuracy of the network on test images: 89.74
# Test Accuracy of 0: 90.0
# Test Accuracy of 1: 91.2
# Test Accuracy of 2: 90.2
# Test Accuracy of 3: 82.2
# Test Accuracy of 4: 92.4
# Test Accuracy of 5: 90.0
# Test Accuracy of 6: 92.0
# Test Accuracy of 7: 91.2
# Test Accuracy of 8: 86.4
# Test Accuracy of 9: 91.8
# Epoch:[21]-Iteration:[100], training loss: 0.394
# Epoch:[21]-Iteration:[200], training loss: 0.402
# Time cost of one epoch: [87]s
# Epoch:[21], training accuracy: 87.4, training loss: 0.400
# Accuracy of the network on test images: 90.08
# Test Accuracy of 0: 89.6
# Test Accuracy of 1: 90.8
# Test Accuracy of 2: 89.8
# Test Accuracy of 3: 85.2
# Test Accuracy of 4: 92.0
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 91.4
# Test Accuracy of 7: 92.6
# Test Accuracy of 8: 87.4
# Test Accuracy of 9: 89.6
# Epoch:[22]-Iteration:[100], training loss: 0.384
# Epoch:[22]-Iteration:[200], training loss: 0.384
# Time cost of one epoch: [87]s
# Epoch:[22], training accuracy: 87.9, training loss: 0.385
# Accuracy of the network on test images: 89.96
# Test Accuracy of 0: 90.0
# Test Accuracy of 1: 87.6
# Test Accuracy of 2: 90.6
# Test Accuracy of 3: 87.0
# Test Accuracy of 4: 93.4
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 89.8
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 84.8
# Test Accuracy of 9: 89.4
# Epoch:[23]-Iteration:[100], training loss: 0.368
# Epoch:[23]-Iteration:[200], training loss: 0.379
# Time cost of one epoch: [87]s
# Epoch:[23], training accuracy: 87.8, training loss: 0.382
# Accuracy of the network on test images: 90.66
# Test Accuracy of 0: 91.8
# Test Accuracy of 1: 91.2
# Test Accuracy of 2: 89.0
# Test Accuracy of 3: 88.4
# Test Accuracy of 4: 91.2
# Test Accuracy of 5: 91.2
# Test Accuracy of 6: 92.6
# Test Accuracy of 7: 93.8
# Test Accuracy of 8: 85.4
# Test Accuracy of 9: 92.0
# Epoch:[24]-Iteration:[100], training loss: 0.373
# Epoch:[24]-Iteration:[200], training loss: 0.377
# Time cost of one epoch: [87]s
# Epoch:[24], training accuracy: 88.1, training loss: 0.379
# Accuracy of the network on test images: 90.64
# Test Accuracy of 0: 92.8
# Test Accuracy of 1: 90.4
# Test Accuracy of 2: 91.8
# Test Accuracy of 3: 85.6
# Test Accuracy of 4: 91.6
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 91.8
# Test Accuracy of 7: 93.6
# Test Accuracy of 8: 87.8
# Test Accuracy of 9: 90.6
# Epoch:[25]-Iteration:[100], training loss: 0.379
# Epoch:[25]-Iteration:[200], training loss: 0.378
# Time cost of one epoch: [87]s
# Epoch:[25], training accuracy: 88.0, training loss: 0.377
# Accuracy of the network on test images: 90.52
# Test Accuracy of 0: 92.2
# Test Accuracy of 1: 90.2
# Test Accuracy of 2: 89.8
# Test Accuracy of 3: 86.8
# Test Accuracy of 4: 93.0
# Test Accuracy of 5: 86.4
# Test Accuracy of 6: 92.0
# Test Accuracy of 7: 94.4
# Test Accuracy of 8: 88.8
# Test Accuracy of 9: 91.6
# Epoch:[26]-Iteration:[100], training loss: 0.365
# Epoch:[26]-Iteration:[200], training loss: 0.370
# Time cost of one epoch: [87]s
# Epoch:[26], training accuracy: 88.2, training loss: 0.371
# Accuracy of the network on test images: 90.56
# Test Accuracy of 0: 89.6
# Test Accuracy of 1: 89.4
# Test Accuracy of 2: 90.2
# Test Accuracy of 3: 88.8
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 89.8
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 88.6
# Test Accuracy of 9: 89.4
# Epoch:[27]-Iteration:[100], training loss: 0.367
# Epoch:[27]-Iteration:[200], training loss: 0.368
# Time cost of one epoch: [88]s
# Epoch:[27], training accuracy: 88.5, training loss: 0.365
# Accuracy of the network on test images: 90.0
# Test Accuracy of 0: 94.2
# Test Accuracy of 1: 86.8
# Test Accuracy of 2: 90.0
# Test Accuracy of 3: 87.0
# Test Accuracy of 4: 91.4
# Test Accuracy of 5: 89.4
# Test Accuracy of 6: 93.2
# Test Accuracy of 7: 96.0
# Test Accuracy of 8: 84.6
# Test Accuracy of 9: 87.4
# Epoch:[28]-Iteration:[100], training loss: 0.370
# Epoch:[28]-Iteration:[200], training loss: 0.369
# Time cost of one epoch: [88]s
# Epoch:[28], training accuracy: 88.5, training loss: 0.369
# Accuracy of the network on test images: 90.12
# Test Accuracy of 0: 89.8
# Test Accuracy of 1: 92.2
# Test Accuracy of 2: 89.2
# Test Accuracy of 3: 81.8
# Test Accuracy of 4: 92.4
# Test Accuracy of 5: 91.0
# Test Accuracy of 6: 92.2
# Test Accuracy of 7: 93.2
# Test Accuracy of 8: 88.8
# Test Accuracy of 9: 90.6
# Epoch:[29]-Iteration:[100], training loss: 0.353
# Epoch:[29]-Iteration:[200], training loss: 0.359
# Time cost of one epoch: [88]s
# Epoch:[29], training accuracy: 88.7, training loss: 0.361
# Accuracy of the network on test images: 90.96
# Test Accuracy of 0: 91.8
# Test Accuracy of 1: 92.6
# Test Accuracy of 2: 91.6
# Test Accuracy of 3: 85.8
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 89.2
# Test Accuracy of 6: 90.2
# Test Accuracy of 7: 92.6
# Test Accuracy of 8: 88.0
# Test Accuracy of 9: 93.0
# Epoch:[30]-Iteration:[100], training loss: 0.359
# Epoch:[30]-Iteration:[200], training loss: 0.357
# Time cost of one epoch: [87]s
# Epoch:[30], training accuracy: 88.6, training loss: 0.356
# Accuracy of the network on test images: 90.76
# Test Accuracy of 0: 90.4
# Test Accuracy of 1: 91.2
# Test Accuracy of 2: 91.6
# Test Accuracy of 3: 88.6
# Test Accuracy of 4: 91.8
# Test Accuracy of 5: 92.0
# Test Accuracy of 6: 90.6
# Test Accuracy of 7: 93.2
# Test Accuracy of 8: 85.8
# Test Accuracy of 9: 92.4
# Epoch:[31]-Iteration:[100], training loss: 0.346
# Epoch:[31]-Iteration:[200], training loss: 0.349
# Time cost of one epoch: [88]s
# Epoch:[31], training accuracy: 89.0, training loss: 0.348
# Accuracy of the network on test images: 90.66
# Test Accuracy of 0: 91.0
# Test Accuracy of 1: 91.8
# Test Accuracy of 2: 91.0
# Test Accuracy of 3: 90.0
# Test Accuracy of 4: 92.6
# Test Accuracy of 5: 89.0
# Test Accuracy of 6: 89.8
# Test Accuracy of 7: 94.0
# Test Accuracy of 8: 86.6
# Test Accuracy of 9: 90.8
# Epoch:[32]-Iteration:[100], training loss: 0.347
# Epoch:[32]-Iteration:[200], training loss: 0.347
# Time cost of one epoch: [88]s
# Epoch:[32], training accuracy: 89.2, training loss: 0.346
# Accuracy of the network on test images: 90.48
# Test Accuracy of 0: 91.4
# Test Accuracy of 1: 91.8
# Test Accuracy of 2: 92.2
# Test Accuracy of 3: 87.0
# Test Accuracy of 4: 94.0
# Test Accuracy of 5: 89.4
# Test Accuracy of 6: 90.6
# Test Accuracy of 7: 91.2
# Test Accuracy of 8: 88.8
# Test Accuracy of 9: 88.4
# Epoch:[33]-Iteration:[100], training loss: 0.338
# Epoch:[33]-Iteration:[200], training loss: 0.342
# Time cost of one epoch: [87]s
# Epoch:[33], training accuracy: 89.1, training loss: 0.342
# Accuracy of the network on test images: 90.68
# Test Accuracy of 0: 92.4
# Test Accuracy of 1: 89.2
# Test Accuracy of 2: 90.8
# Test Accuracy of 3: 91.4
# Test Accuracy of 4: 93.4
# Test Accuracy of 5: 88.2
# Test Accuracy of 6: 89.8
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 85.2
# Test Accuracy of 9: 91.2
# Epoch:[34]-Iteration:[100], training loss: 0.343
# Epoch:[34]-Iteration:[200], training loss: 0.345
# Time cost of one epoch: [87]s
# Epoch:[34], training accuracy: 89.0, training loss: 0.345
# Accuracy of the network on test images: 90.84
# Test Accuracy of 0: 91.6
# Test Accuracy of 1: 89.8
# Test Accuracy of 2: 91.4
# Test Accuracy of 3: 84.8
# Test Accuracy of 4: 92.8
# Test Accuracy of 5: 87.2
# Test Accuracy of 6: 91.0
# Test Accuracy of 7: 94.6
# Test Accuracy of 8: 91.2
# Test Accuracy of 9: 94.0
# Epoch:[35]-Iteration:[100], training loss: 0.347
# Epoch:[35]-Iteration:[200], training loss: 0.342
# Time cost of one epoch: [86]s
# Epoch:[35], training accuracy: 89.1, training loss: 0.343
# Accuracy of the network on test images: 90.54
# Test Accuracy of 0: 94.2
# Test Accuracy of 1: 89.4
# Test Accuracy of 2: 91.8
# Test Accuracy of 3: 87.4
# Test Accuracy of 4: 92.8
# Test Accuracy of 5: 88.8
# Test Accuracy of 6: 90.2
# Test Accuracy of 7: 93.0
# Test Accuracy of 8: 87.2
# Test Accuracy of 9: 90.6
# Epoch:[36]-Iteration:[100], training loss: 0.322
# Epoch:[36]-Iteration:[200], training loss: 0.333
# Time cost of one epoch: [87]s
# Epoch:[36], training accuracy: 89.6, training loss: 0.334
# Accuracy of the network on test images: 90.06
# Test Accuracy of 0: 93.2
# Test Accuracy of 1: 90.2
# Test Accuracy of 2: 92.4
# Test Accuracy of 3: 83.0
# Test Accuracy of 4: 92.2
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 90.6
# Test Accuracy of 7: 93.4
# Test Accuracy of 8: 84.8
# Test Accuracy of 9: 88.6
# Epoch:[37]-Iteration:[100], training loss: 0.339
# Epoch:[37]-Iteration:[200], training loss: 0.341
# Time cost of one epoch: [88]s
# Epoch:[37], training accuracy: 89.3, training loss: 0.342
# Accuracy of the network on test images: 90.76
# Test Accuracy of 0: 94.4
# Test Accuracy of 1: 87.4
# Test Accuracy of 2: 89.2
# Test Accuracy of 3: 86.2
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 89.0
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 87.8
# Test Accuracy of 9: 92.8
# Epoch:[38]-Iteration:[100], training loss: 0.325
# Epoch:[38]-Iteration:[200], training loss: 0.335
# Time cost of one epoch: [87]s
# Epoch:[38], training accuracy: 89.4, training loss: 0.334
# Accuracy of the network on test images: 90.72
# Test Accuracy of 0: 91.0
# Test Accuracy of 1: 89.8
# Test Accuracy of 2: 89.8
# Test Accuracy of 3: 89.4
# Test Accuracy of 4: 93.2
# Test Accuracy of 5: 91.8
# Test Accuracy of 6: 91.4
# Test Accuracy of 7: 93.6
# Test Accuracy of 8: 85.0
# Test Accuracy of 9: 92.2
# Epoch:[39]-Iteration:[100], training loss: 0.331
# Epoch:[39]-Iteration:[200], training loss: 0.328
# Time cost of one epoch: [87]s
# Epoch:[39], training accuracy: 89.8, training loss: 0.330
# Accuracy of the network on test images: 90.16
# Test Accuracy of 0: 90.0
# Test Accuracy of 1: 90.2
# Test Accuracy of 2: 89.0
# Test Accuracy of 3: 88.8
# Test Accuracy of 4: 92.8
# Test Accuracy of 5: 89.2
# Test Accuracy of 6: 90.4
# Test Accuracy of 7: 91.2
# Test Accuracy of 8: 87.6
# Test Accuracy of 9: 92.4
# Epoch:[40]-Iteration:[100], training loss: 0.324
# Epoch:[40]-Iteration:[200], training loss: 0.326
# Time cost of one epoch: [87]s
# Epoch:[40], training accuracy: 89.8, training loss: 0.328
# Accuracy of the network on test images: 90.5
# Test Accuracy of 0: 90.4
# Test Accuracy of 1: 89.6
# Test Accuracy of 2: 91.6
# Test Accuracy of 3: 85.0
# Test Accuracy of 4: 94.4
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 88.6
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 89.8
# Test Accuracy of 9: 90.4
# Epoch:[41]-Iteration:[100], training loss: 0.303
# Epoch:[41]-Iteration:[200], training loss: 0.307
# Time cost of one epoch: [86]s
# Epoch:[41], training accuracy: 90.3, training loss: 0.307
# Accuracy of the network on test images: 91.28
# Test Accuracy of 0: 91.0
# Test Accuracy of 1: 90.2
# Test Accuracy of 2: 92.8
# Test Accuracy of 3: 85.2
# Test Accuracy of 4: 94.4
# Test Accuracy of 5: 92.0
# Test Accuracy of 6: 92.8
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 86.6
# Test Accuracy of 9: 92.8
# Epoch:[42]-Iteration:[100], training loss: 0.297
# Epoch:[42]-Iteration:[200], training loss: 0.294
# Time cost of one epoch: [87]s
# Epoch:[42], training accuracy: 90.7, training loss: 0.297
# Accuracy of the network on test images: 91.06
# Test Accuracy of 0: 91.8
# Test Accuracy of 1: 89.6
# Test Accuracy of 2: 91.4
# Test Accuracy of 3: 89.0
# Test Accuracy of 4: 95.4
# Test Accuracy of 5: 87.2
# Test Accuracy of 6: 90.6
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 89.0
# Test Accuracy of 9: 91.8
# Epoch:[43]-Iteration:[100], training loss: 0.300
# Epoch:[43]-Iteration:[200], training loss: 0.304
# Time cost of one epoch: [87]s
# Epoch:[43], training accuracy: 90.3, training loss: 0.303
# Accuracy of the network on test images: 90.94
# Test Accuracy of 0: 91.2
# Test Accuracy of 1: 92.4
# Test Accuracy of 2: 91.2
# Test Accuracy of 3: 86.2
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 89.2
# Test Accuracy of 6: 91.6
# Test Accuracy of 7: 93.2
# Test Accuracy of 8: 87.8
# Test Accuracy of 9: 91.8
# Epoch:[44]-Iteration:[100], training loss: 0.293
# Epoch:[44]-Iteration:[200], training loss: 0.295
# Time cost of one epoch: [87]s
# Epoch:[44], training accuracy: 90.5, training loss: 0.297
# Accuracy of the network on test images: 91.44
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 90.0
# Test Accuracy of 3: 87.0
# Test Accuracy of 4: 95.8
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 93.2
# Test Accuracy of 7: 93.8
# Test Accuracy of 8: 85.6
# Test Accuracy of 9: 93.0
# Epoch:[45]-Iteration:[100], training loss: 0.281
# Epoch:[45]-Iteration:[200], training loss: 0.288
# Time cost of one epoch: [87]s
# Epoch:[45], training accuracy: 90.8, training loss: 0.292
# Accuracy of the network on test images: 91.18
# Test Accuracy of 0: 91.8
# Test Accuracy of 1: 90.8
# Test Accuracy of 2: 89.0
# Test Accuracy of 3: 89.2
# Test Accuracy of 4: 94.8
# Test Accuracy of 5: 89.0
# Test Accuracy of 6: 92.0
# Test Accuracy of 7: 94.2
# Test Accuracy of 8: 88.8
# Test Accuracy of 9: 92.2
# Epoch:[46]-Iteration:[100], training loss: 0.303
# Epoch:[46]-Iteration:[200], training loss: 0.295
# Time cost of one epoch: [87]s
# Epoch:[46], training accuracy: 90.5, training loss: 0.296
# Accuracy of the network on test images: 90.98
# Test Accuracy of 0: 89.4
# Test Accuracy of 1: 90.8
# Test Accuracy of 2: 92.6
# Test Accuracy of 3: 89.0
# Test Accuracy of 4: 95.8
# Test Accuracy of 5: 91.8
# Test Accuracy of 6: 89.4
# Test Accuracy of 7: 93.8
# Test Accuracy of 8: 86.8
# Test Accuracy of 9: 90.4
# Epoch:[47]-Iteration:[100], training loss: 0.285
# Epoch:[47]-Iteration:[200], training loss: 0.281
# Time cost of one epoch: [85]s
# Epoch:[47], training accuracy: 91.1, training loss: 0.283
# Accuracy of the network on test images: 91.28
# Test Accuracy of 0: 90.4
# Test Accuracy of 1: 91.4
# Test Accuracy of 2: 90.8
# Test Accuracy of 3: 88.4
# Test Accuracy of 4: 91.4
# Test Accuracy of 5: 89.2
# Test Accuracy of 6: 92.2
# Test Accuracy of 7: 94.6
# Test Accuracy of 8: 90.0
# Test Accuracy of 9: 94.4
# Epoch:[48]-Iteration:[100], training loss: 0.274
# Epoch:[48]-Iteration:[200], training loss: 0.286
# Time cost of one epoch: [87]s
# Epoch:[48], training accuracy: 91.0, training loss: 0.284
# Accuracy of the network on test images: 91.78
# Test Accuracy of 0: 93.0
# Test Accuracy of 1: 89.6
# Test Accuracy of 2: 92.8
# Test Accuracy of 3: 88.6
# Test Accuracy of 4: 95.0
# Test Accuracy of 5: 90.6
# Test Accuracy of 6: 92.0
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 89.0
# Test Accuracy of 9: 91.6
# Epoch:[49]-Iteration:[100], training loss: 0.283
# Epoch:[49]-Iteration:[200], training loss: 0.280
# Time cost of one epoch: [87]s
# Epoch:[49], training accuracy: 91.0, training loss: 0.280
# Accuracy of the network on test images: 91.0
# Test Accuracy of 0: 91.6
# Test Accuracy of 1: 88.8
# Test Accuracy of 2: 89.4
# Test Accuracy of 3: 88.4
# Test Accuracy of 4: 94.4
# Test Accuracy of 5: 88.6
# Test Accuracy of 6: 91.2
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 90.4
# Test Accuracy of 9: 92.4
# Epoch:[50]-Iteration:[100], training loss: 0.277
# Epoch:[50]-Iteration:[200], training loss: 0.275
# Time cost of one epoch: [86]s
# Epoch:[50], training accuracy: 91.2, training loss: 0.276
# Accuracy of the network on test images: 91.7
# Test Accuracy of 0: 92.8
# Test Accuracy of 1: 91.6
# Test Accuracy of 2: 91.2
# Test Accuracy of 3: 87.6
# Test Accuracy of 4: 94.2
# Test Accuracy of 5: 89.6
# Test Accuracy of 6: 91.0
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 90.4
# Test Accuracy of 9: 92.8
# Finished Training
# time required 4624.01s

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(list(range(1,epoch+1)), history["train_accuracy"], label="Train")
plt.plot(list(range(1,epoch+1)), history["val_accuracy"], label="Test")
plt.xlabel("Epoch")
ax = plt.gca()
ax.set_ylim([90, 95])
plt.ylabel("Accuracy")
plt.legend()
plt.show()
print("Epoch with max test accuracy:", history["val_accuracy"].index(min(history["val_accuracy"]))+1)
# Out:
# Epoch with max test accuracy: 1
