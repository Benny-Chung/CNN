# %%
from __future__ import print_function, division

import torch
import torch.optim as optim

from torch.optim import lr_scheduler
from torchvision import datasets, transforms
import time
import os

import torch.nn as nn

# TODO: You can modify the network architecture
class Net(nn.Module):
    """
    Input - 1x32x32
    Output - 10
    """
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=7, padding=3, stride=2),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(p=0.3),

            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Dropout(p=0.3),

            nn.Flatten(), 
            nn.Linear(256*4*4, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
            )
        
    def forward(self, xb):
        return self.network(xb)

# %%
from random import randrange
# TODO: You can try different augmentation strategies
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomChoice([transforms.Pad(padding=4, fill=(randrange(256),randrange(256),randrange(256))), transforms.ElasticTransform(),transforms.GaussianBlur((3,3))]),
        transforms.RandomGrayscale(0.15),
        transforms.RandomAffine(degrees=10, translate=(0,0.1)),
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),

    ]),
    'test': transforms.Compose([
        transforms.Resize((32,32)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    ]),
}

# %%
data_dir = 'data' # Suppose the dataset is stored under this folder
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'test']} # Read train and test sets, respectively.

train_dataloader = torch.utils.data.DataLoader(image_datasets['train'], batch_size=128,
                                             shuffle=True, num_workers=4)

test_dataloader = torch.utils.data.DataLoader(image_datasets['test'], batch_size=128,
                                             shuffle=False, num_workers=4)

train_size =len(image_datasets['train'])


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # Set device to "cpu" if you have no gpu

# %%
history = dict()

def train_test(model, criterion, optimizer, scheduler, num_epochs=25):
    train_loss = []
    train_accuracy = []
    val_loss = [] 
    val_accuracy = []
    model.train()
    for epoch in range(num_epochs):
        running_training_loss = 0.0
        running_training_accuracy = 0.0
        iteration_training_loss = 0.0
        total_training_predictions = 0
       
        start_time = time.time()
        for i, data in enumerate(train_dataloader, 0):
            inputs, labels = data[0].to(device), data[1].to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_training_loss += loss.item()*inputs.size(0)
            
            _, predicted = torch.max(outputs.data, 1)
            total_training_predictions += labels.size(0)
            running_training_accuracy += (predicted == labels).sum().item()
            iteration_training_loss += loss.item() 
            if (i+1) % 100 == 0:
                print('Epoch:[%d]-Iteration:[%d], training loss: %.3f' %
                      (epoch + 1,i+1,iteration_training_loss/(i+1)))
        end_time = time.time()
        print('Time cost of one epoch: [%d]s' % (end_time-start_time))
        
        epoch_training_accuracy = running_training_accuracy / train_size*100
        epoch_training_loss = running_training_loss / train_size
        
        print('Epoch:[%d], training accuracy: %.1f, training loss: %.3f' %
              (epoch + 1,epoch_training_accuracy, epoch_training_loss))
        
        train_loss.append(epoch_training_loss)
        train_accuracy.append(epoch_training_accuracy)
        
        correct = 0
        total = 0
        labelsCorrect = [0 for i in range(10)]
        labelsTotal = [0 for i in range(10)]
        model.eval()
        # Since we're not training, we don't need to calculate the gradients for our outputs
        with torch.no_grad():
            for data in test_dataloader:
                images, labels = data[0].to(device), data[1].to(device)
                # calculate outputs by running images through the network
                outputs = model(images)
                # the class with the highest energy is what we choose as prediction
                _, predicted = torch.max(outputs.data, 1)
                tmp = (predicted == labels)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                for i in range(labels.size(0)): 
                    label = labels.data[i]
                    labelsCorrect[label] += tmp[i]
                    labelsTotal[label] += 1
        accuracy = float(100) * correct / total
        print(f'Accuracy of the network on test images: {accuracy}')
        for i in range(10): 
            acc = (labelsCorrect[i]/labelsTotal[i]).item
            print(f"Test Accuracy of {i}: {round((labelsCorrect[i]/labelsTotal[i]).item()*100,2)}")        
        val_accuracy.append(accuracy)
        scheduler.step()
        
    print('Finished Training')

    history['train_loss'] = train_loss
    history['train_accuracy'] = train_accuracy
    history['val_accuracy'] = val_accuracy

    return history, accuracy

# %%
epoch = 40

if __name__ == '__main__':
    end = time.time()
    model_ft = Net().to(device) # Model initialization
    print(model_ft.network)
    criterion = nn.CrossEntropyLoss() # Loss function initialization

    # TODO: Adjust the following hyper-parameters: initial learning rate, decay strategy of the learning rate, 
    #       number of training epochs
    optimizer_ft = optim.AdamW(model_ft.parameters(), lr=0.001, weight_decay=0.5) # The initial learning rate is 1e-3

    exp_lr_scheduler = lr_scheduler.MultiStepLR(optimizer_ft, milestones=[20,30], gamma=0.05) 
    
    history, accuracy = train_test(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
               num_epochs=epoch)
    
    print("time required %.2fs" %(time.time() - end))
# Out:
# Sequential(
#   (0): Conv2d(3, 32, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#   (1): ReLU()
#   (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): ReLU()
#   (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (5): Dropout(p=0.3, inplace=False)
#   (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (7): ReLU()
#   (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (9): ReLU()
#   (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (11): Dropout(p=0.3, inplace=False)
#   (12): Flatten(start_dim=1, end_dim=-1)
#   (13): Linear(in_features=4096, out_features=128, bias=True)
#   (14): ReLU()
#   (15): Linear(in_features=128, out_features=10, bias=True)
# )
# Epoch:[1]-Iteration:[100], training loss: 2.303
# Epoch:[1]-Iteration:[200], training loss: 2.023
# Time cost of one epoch: [48]s
# Epoch:[1], training accuracy: 29.7, training loss: 1.897
# Accuracy of the network on test images: 76.84
# Test Accuracy of 0: 85.2
# Test Accuracy of 1: 86.6
# Test Accuracy of 2: 84.2
# Test Accuracy of 3: 45.6
# Test Accuracy of 4: 83.4
# Test Accuracy of 5: 84.8
# Test Accuracy of 6: 69.8
# Test Accuracy of 7: 83.2
# Test Accuracy of 8: 64.0
# Test Accuracy of 9: 81.6
# Epoch:[2]-Iteration:[100], training loss: 0.866
# Epoch:[2]-Iteration:[200], training loss: 0.789
# Time cost of one epoch: [47]s
# Epoch:[2], training accuracy: 75.3, training loss: 0.770
# Accuracy of the network on test images: 85.84
# Test Accuracy of 0: 87.8
# Test Accuracy of 1: 89.2
# Test Accuracy of 2: 82.6
# Test Accuracy of 3: 79.8
# Test Accuracy of 4: 93.0
# Test Accuracy of 5: 73.6
# Test Accuracy of 6: 87.0
# Test Accuracy of 7: 92.6
# Test Accuracy of 8: 80.8
# Test Accuracy of 9: 92.0
# Epoch:[3]-Iteration:[100], training loss: 0.581
# Epoch:[3]-Iteration:[200], training loss: 0.567
# Time cost of one epoch: [47]s
# Epoch:[3], training accuracy: 82.4, training loss: 0.561
# Accuracy of the network on test images: 89.04
# Test Accuracy of 0: 92.4
# Test Accuracy of 1: 85.2
# Test Accuracy of 2: 90.4
# Test Accuracy of 3: 85.8
# Test Accuracy of 4: 93.0
# Test Accuracy of 5: 89.4
# Test Accuracy of 6: 84.0
# Test Accuracy of 7: 93.0
# Test Accuracy of 8: 88.2
# Test Accuracy of 9: 89.0
# Epoch:[4]-Iteration:[100], training loss: 0.500
# Epoch:[4]-Iteration:[200], training loss: 0.488
# Time cost of one epoch: [48]s
# Epoch:[4], training accuracy: 84.8, training loss: 0.486
# Accuracy of the network on test images: 89.78
# Test Accuracy of 0: 92.0
# Test Accuracy of 1: 92.2
# Test Accuracy of 2: 92.0
# Test Accuracy of 3: 83.0
# Test Accuracy of 4: 91.0
# Test Accuracy of 5: 90.2
# Test Accuracy of 6: 91.8
# Test Accuracy of 7: 87.6
# Test Accuracy of 8: 86.4
# Test Accuracy of 9: 91.6
# Epoch:[5]-Iteration:[100], training loss: 0.454
# Epoch:[5]-Iteration:[200], training loss: 0.445
# Time cost of one epoch: [48]s
# Epoch:[5], training accuracy: 86.1, training loss: 0.442
# Accuracy of the network on test images: 90.54
# Test Accuracy of 0: 88.2
# Test Accuracy of 1: 95.0
# Test Accuracy of 2: 89.8
# Test Accuracy of 3: 84.6
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 94.6
# Test Accuracy of 6: 87.8
# Test Accuracy of 7: 91.6
# Test Accuracy of 8: 87.8
# Test Accuracy of 9: 91.4
# Epoch:[6]-Iteration:[100], training loss: 0.409
# Epoch:[6]-Iteration:[200], training loss: 0.410
# Time cost of one epoch: [49]s
# Epoch:[6], training accuracy: 87.0, training loss: 0.413
# Accuracy of the network on test images: 91.12
# Test Accuracy of 0: 93.4
# Test Accuracy of 1: 88.0
# Test Accuracy of 2: 90.2
# Test Accuracy of 3: 82.0
# Test Accuracy of 4: 95.6
# Test Accuracy of 5: 93.8
# Test Accuracy of 6: 93.6
# Test Accuracy of 7: 94.2
# Test Accuracy of 8: 86.8
# Test Accuracy of 9: 93.6
# Epoch:[7]-Iteration:[100], training loss: 0.383
# Epoch:[7]-Iteration:[200], training loss: 0.382
# Time cost of one epoch: [48]s
# Epoch:[7], training accuracy: 88.0, training loss: 0.386
# Accuracy of the network on test images: 91.5
# Test Accuracy of 0: 94.4
# Test Accuracy of 1: 94.2
# Test Accuracy of 2: 92.6
# Test Accuracy of 3: 86.8
# Test Accuracy of 4: 94.6
# Test Accuracy of 5: 91.4
# Test Accuracy of 6: 89.0
# Test Accuracy of 7: 95.6
# Test Accuracy of 8: 89.4
# Test Accuracy of 9: 87.0
# Epoch:[8]-Iteration:[100], training loss: 0.365
# Epoch:[8]-Iteration:[200], training loss: 0.374
# Time cost of one epoch: [48]s
# Epoch:[8], training accuracy: 88.3, training loss: 0.377
# Accuracy of the network on test images: 92.12
# Test Accuracy of 0: 94.0
# Test Accuracy of 1: 89.4
# Test Accuracy of 2: 93.0
# Test Accuracy of 3: 89.4
# Test Accuracy of 4: 96.8
# Test Accuracy of 5: 90.2
# Test Accuracy of 6: 88.8
# Test Accuracy of 7: 93.6
# Test Accuracy of 8: 91.4
# Test Accuracy of 9: 94.6
# Epoch:[9]-Iteration:[100], training loss: 0.347
# Epoch:[9]-Iteration:[200], training loss: 0.367
# Time cost of one epoch: [48]s
# Epoch:[9], training accuracy: 88.8, training loss: 0.367
# Accuracy of the network on test images: 92.4
# Test Accuracy of 0: 91.6
# Test Accuracy of 1: 94.6
# Test Accuracy of 2: 92.0
# Test Accuracy of 3: 89.2
# Test Accuracy of 4: 93.8
# Test Accuracy of 5: 92.0
# Test Accuracy of 6: 94.2
# Test Accuracy of 7: 93.0
# Test Accuracy of 8: 92.4
# Test Accuracy of 9: 91.2
# Epoch:[10]-Iteration:[100], training loss: 0.334
# Epoch:[10]-Iteration:[200], training loss: 0.342
# Time cost of one epoch: [48]s
# Epoch:[10], training accuracy: 89.5, training loss: 0.345
# Accuracy of the network on test images: 92.64
# Test Accuracy of 0: 94.6
# Test Accuracy of 1: 92.6
# Test Accuracy of 2: 94.0
# Test Accuracy of 3: 88.2
# Test Accuracy of 4: 97.4
# Test Accuracy of 5: 92.6
# Test Accuracy of 6: 93.2
# Test Accuracy of 7: 91.8
# Test Accuracy of 8: 90.8
# Test Accuracy of 9: 91.2
# Epoch:[11]-Iteration:[100], training loss: 0.350
# Epoch:[11]-Iteration:[200], training loss: 0.349
# Time cost of one epoch: [48]s
# Epoch:[11], training accuracy: 89.3, training loss: 0.348
# Accuracy of the network on test images: 92.0
# Test Accuracy of 0: 95.0
# Test Accuracy of 1: 94.0
# Test Accuracy of 2: 90.2
# Test Accuracy of 3: 87.0
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 91.4
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.8
# Test Accuracy of 8: 87.4
# Test Accuracy of 9: 88.8
# Epoch:[12]-Iteration:[100], training loss: 0.348
# Epoch:[12]-Iteration:[200], training loss: 0.344
# Time cost of one epoch: [49]s
# Epoch:[12], training accuracy: 89.5, training loss: 0.340
# Accuracy of the network on test images: 92.24
# Test Accuracy of 0: 92.2
# Test Accuracy of 1: 91.0
# Test Accuracy of 2: 90.8
# Test Accuracy of 3: 86.8
# Test Accuracy of 4: 96.8
# Test Accuracy of 5: 91.8
# Test Accuracy of 6: 93.2
# Test Accuracy of 7: 97.0
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 90.0
# Epoch:[13]-Iteration:[100], training loss: 0.324
# Epoch:[13]-Iteration:[200], training loss: 0.327
# Time cost of one epoch: [49]s
# Epoch:[13], training accuracy: 90.0, training loss: 0.329
# Accuracy of the network on test images: 92.84
# Test Accuracy of 0: 91.2
# Test Accuracy of 1: 94.0
# Test Accuracy of 2: 94.8
# Test Accuracy of 3: 86.8
# Test Accuracy of 4: 93.4
# Test Accuracy of 5: 92.8
# Test Accuracy of 6: 92.6
# Test Accuracy of 7: 96.8
# Test Accuracy of 8: 91.0
# Test Accuracy of 9: 95.0
# Epoch:[14]-Iteration:[100], training loss: 0.336
# Epoch:[14]-Iteration:[200], training loss: 0.330
# Time cost of one epoch: [49]s
# Epoch:[14], training accuracy: 90.0, training loss: 0.325
# Accuracy of the network on test images: 92.16
# Test Accuracy of 0: 95.2
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 91.4
# Test Accuracy of 3: 87.4
# Test Accuracy of 4: 91.0
# Test Accuracy of 5: 92.2
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 88.6
# Test Accuracy of 9: 93.8
# Epoch:[15]-Iteration:[100], training loss: 0.320
# Epoch:[15]-Iteration:[200], training loss: 0.313
# Time cost of one epoch: [49]s
# Epoch:[15], training accuracy: 90.5, training loss: 0.316
# Accuracy of the network on test images: 91.96
# Test Accuracy of 0: 91.2
# Test Accuracy of 1: 91.4
# Test Accuracy of 2: 92.2
# Test Accuracy of 3: 91.6
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 91.8
# Test Accuracy of 6: 85.0
# Test Accuracy of 7: 96.0
# Test Accuracy of 8: 89.4
# Test Accuracy of 9: 95.8
# Epoch:[16]-Iteration:[100], training loss: 0.301
# Epoch:[16]-Iteration:[200], training loss: 0.313
# Time cost of one epoch: [48]s
# Epoch:[16], training accuracy: 90.5, training loss: 0.315
# Accuracy of the network on test images: 92.26
# Test Accuracy of 0: 94.0
# Test Accuracy of 1: 88.8
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 89.0
# Test Accuracy of 4: 97.0
# Test Accuracy of 5: 93.2
# Test Accuracy of 6: 90.4
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 94.8
# Test Accuracy of 9: 86.4
# Epoch:[17]-Iteration:[100], training loss: 0.315
# Epoch:[17]-Iteration:[200], training loss: 0.318
# Time cost of one epoch: [49]s
# Epoch:[17], training accuracy: 90.4, training loss: 0.314
# Accuracy of the network on test images: 92.88
# Test Accuracy of 0: 94.2
# Test Accuracy of 1: 90.0
# Test Accuracy of 2: 94.4
# Test Accuracy of 3: 92.4
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 91.4
# Test Accuracy of 6: 91.6
# Test Accuracy of 7: 94.4
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 91.6
# Epoch:[18]-Iteration:[100], training loss: 0.293
# Epoch:[18]-Iteration:[200], training loss: 0.305
# Time cost of one epoch: [48]s
# Epoch:[18], training accuracy: 90.7, training loss: 0.305
# Accuracy of the network on test images: 92.18
# Test Accuracy of 0: 93.6
# Test Accuracy of 1: 87.6
# Test Accuracy of 2: 91.8
# Test Accuracy of 3: 88.4
# Test Accuracy of 4: 97.6
# Test Accuracy of 5: 90.4
# Test Accuracy of 6: 94.2
# Test Accuracy of 7: 97.4
# Test Accuracy of 8: 88.2
# Test Accuracy of 9: 92.6
# Epoch:[19]-Iteration:[100], training loss: 0.297
# Epoch:[19]-Iteration:[200], training loss: 0.304
# Time cost of one epoch: [49]s
# Epoch:[19], training accuracy: 90.8, training loss: 0.304
# Accuracy of the network on test images: 92.44
# Test Accuracy of 0: 96.2
# Test Accuracy of 1: 92.8
# Test Accuracy of 2: 94.8
# Test Accuracy of 3: 89.2
# Test Accuracy of 4: 97.2
# Test Accuracy of 5: 86.6
# Test Accuracy of 6: 92.6
# Test Accuracy of 7: 91.8
# Test Accuracy of 8: 90.8
# Test Accuracy of 9: 92.4
# Epoch:[20]-Iteration:[100], training loss: 0.296
# Epoch:[20]-Iteration:[200], training loss: 0.297
# Time cost of one epoch: [48]s
# Epoch:[20], training accuracy: 90.8, training loss: 0.300
# Accuracy of the network on test images: 92.32
# Test Accuracy of 0: 91.8
# Test Accuracy of 1: 92.0
# Test Accuracy of 2: 95.6
# Test Accuracy of 3: 87.0
# Test Accuracy of 4: 97.2
# Test Accuracy of 5: 90.6
# Test Accuracy of 6: 89.4
# Test Accuracy of 7: 96.0
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 91.4
# Epoch:[21]-Iteration:[100], training loss: 0.245
# Epoch:[21]-Iteration:[200], training loss: 0.241
# Time cost of one epoch: [49]s
# Epoch:[21], training accuracy: 92.7, training loss: 0.242
# Accuracy of the network on test images: 93.68
# Test Accuracy of 0: 95.2
# Test Accuracy of 1: 93.0
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 91.0
# Test Accuracy of 4: 96.4
# Test Accuracy of 5: 93.4
# Test Accuracy of 6: 93.8
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 92.8
# Epoch:[22]-Iteration:[100], training loss: 0.224
# Epoch:[22]-Iteration:[200], training loss: 0.223
# Time cost of one epoch: [48]s
# Epoch:[22], training accuracy: 93.3, training loss: 0.224
# Accuracy of the network on test images: 93.98
# Test Accuracy of 0: 95.4
# Test Accuracy of 1: 92.8
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 91.2
# Test Accuracy of 4: 96.6
# Test Accuracy of 5: 94.2
# Test Accuracy of 6: 94.0
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.2
# Test Accuracy of 9: 94.8
# Epoch:[23]-Iteration:[100], training loss: 0.212
# Epoch:[23]-Iteration:[200], training loss: 0.221
# Time cost of one epoch: [48]s
# Epoch:[23], training accuracy: 93.3, training loss: 0.222
# Accuracy of the network on test images: 93.86
# Test Accuracy of 0: 94.6
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 94.0
# Test Accuracy of 3: 89.6
# Test Accuracy of 4: 96.2
# Test Accuracy of 5: 94.2
# Test Accuracy of 6: 94.2
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 94.8
# Epoch:[24]-Iteration:[100], training loss: 0.213
# Epoch:[24]-Iteration:[200], training loss: 0.211
# Time cost of one epoch: [49]s
# Epoch:[24], training accuracy: 93.7, training loss: 0.213
# Accuracy of the network on test images: 93.94
# Test Accuracy of 0: 94.6
# Test Accuracy of 1: 93.8
# Test Accuracy of 2: 93.6
# Test Accuracy of 3: 90.2
# Test Accuracy of 4: 97.0
# Test Accuracy of 5: 94.4
# Test Accuracy of 6: 94.2
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.0
# Test Accuracy of 9: 94.4
# Epoch:[25]-Iteration:[100], training loss: 0.212
# Epoch:[25]-Iteration:[200], training loss: 0.216
# Time cost of one epoch: [48]s
# Epoch:[25], training accuracy: 93.7, training loss: 0.215
# Accuracy of the network on test images: 93.98
# Test Accuracy of 0: 94.8
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 94.2
# Test Accuracy of 3: 91.2
# Test Accuracy of 4: 97.2
# Test Accuracy of 5: 93.8
# Test Accuracy of 6: 94.6
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 92.0
# Test Accuracy of 9: 93.8
# Epoch:[26]-Iteration:[100], training loss: 0.211
# Epoch:[26]-Iteration:[200], training loss: 0.206
# Time cost of one epoch: [49]s
# Epoch:[26], training accuracy: 93.9, training loss: 0.210
# Accuracy of the network on test images: 93.94
# Test Accuracy of 0: 94.6
# Test Accuracy of 1: 93.0
# Test Accuracy of 2: 93.4
# Test Accuracy of 3: 91.2
# Test Accuracy of 4: 97.4
# Test Accuracy of 5: 92.4
# Test Accuracy of 6: 94.4
# Test Accuracy of 7: 95.4
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 94.8
# Epoch:[27]-Iteration:[100], training loss: 0.199
# Epoch:[27]-Iteration:[200], training loss: 0.206
# Time cost of one epoch: [48]s
# Epoch:[27], training accuracy: 94.1, training loss: 0.204
# Accuracy of the network on test images: 94.08
# Test Accuracy of 0: 94.4
# Test Accuracy of 1: 94.0
# Test Accuracy of 2: 95.0
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.4
# Test Accuracy of 5: 93.6
# Test Accuracy of 6: 94.4
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 94.4
# Epoch:[28]-Iteration:[100], training loss: 0.200
# Epoch:[28]-Iteration:[200], training loss: 0.205
# Time cost of one epoch: [48]s
# Epoch:[28], training accuracy: 94.0, training loss: 0.205
# Accuracy of the network on test images: 93.98
# Test Accuracy of 0: 94.0
# Test Accuracy of 1: 93.0
# Test Accuracy of 2: 94.6
# Test Accuracy of 3: 89.8
# Test Accuracy of 4: 96.2
# Test Accuracy of 5: 94.6
# Test Accuracy of 6: 93.4
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 93.8
# Test Accuracy of 9: 95.4
# Epoch:[29]-Iteration:[100], training loss: 0.201
# Epoch:[29]-Iteration:[200], training loss: 0.201
# Time cost of one epoch: [49]s
# Epoch:[29], training accuracy: 94.1, training loss: 0.200
# Accuracy of the network on test images: 94.04
# Test Accuracy of 0: 94.8
# Test Accuracy of 1: 93.0
# Test Accuracy of 2: 94.6
# Test Accuracy of 3: 91.8
# Test Accuracy of 4: 96.4
# Test Accuracy of 5: 93.2
# Test Accuracy of 6: 94.2
# Test Accuracy of 7: 94.4
# Test Accuracy of 8: 93.2
# Test Accuracy of 9: 94.8
# Epoch:[30]-Iteration:[100], training loss: 0.203
# Epoch:[30]-Iteration:[200], training loss: 0.194
# Time cost of one epoch: [50]s
# Epoch:[30], training accuracy: 94.2, training loss: 0.196
# Accuracy of the network on test images: 94.02
# Test Accuracy of 0: 94.4
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 94.6
# Test Accuracy of 3: 90.2
# Test Accuracy of 4: 95.2
# Test Accuracy of 5: 94.0
# Test Accuracy of 6: 95.0
# Test Accuracy of 7: 94.8
# Test Accuracy of 8: 94.0
# Test Accuracy of 9: 94.8
# Epoch:[31]-Iteration:[100], training loss: 0.193
# Epoch:[31]-Iteration:[200], training loss: 0.193
# Time cost of one epoch: [49]s
# Epoch:[31], training accuracy: 94.3, training loss: 0.194
# Accuracy of the network on test images: 94.06
# Test Accuracy of 0: 94.8
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 95.0
# Test Accuracy of 3: 90.6
# Test Accuracy of 4: 95.8
# Test Accuracy of 5: 93.6
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 94.8
# Epoch:[32]-Iteration:[100], training loss: 0.194
# Epoch:[32]-Iteration:[200], training loss: 0.193
# Time cost of one epoch: [49]s
# Epoch:[32], training accuracy: 94.3, training loss: 0.195
# Accuracy of the network on test images: 94.04
# Test Accuracy of 0: 94.8
# Test Accuracy of 1: 93.6
# Test Accuracy of 2: 95.0
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 95.8
# Test Accuracy of 5: 93.4
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 92.4
# Test Accuracy of 9: 94.8
# Epoch:[33]-Iteration:[100], training loss: 0.200
# Epoch:[33]-Iteration:[200], training loss: 0.196
# Time cost of one epoch: [49]s
# Epoch:[33], training accuracy: 94.4, training loss: 0.194
# Accuracy of the network on test images: 93.98
# Test Accuracy of 0: 94.8
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 94.6
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 95.8
# Test Accuracy of 5: 93.2
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 92.6
# Test Accuracy of 9: 94.8
# Epoch:[34]-Iteration:[100], training loss: 0.198
# Epoch:[34]-Iteration:[200], training loss: 0.196
# Time cost of one epoch: [48]s
# Epoch:[34], training accuracy: 94.4, training loss: 0.193
# Accuracy of the network on test images: 94.08
# Test Accuracy of 0: 94.8
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 94.8
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 95.8
# Test Accuracy of 5: 93.6
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 93.0
# Test Accuracy of 9: 94.8
# Epoch:[35]-Iteration:[100], training loss: 0.192
# Epoch:[35]-Iteration:[200], training loss: 0.195
# Time cost of one epoch: [49]s
# Epoch:[35], training accuracy: 94.4, training loss: 0.194
# Accuracy of the network on test images: 94.08
# Test Accuracy of 0: 94.8
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 94.6
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 95.8
# Test Accuracy of 5: 93.6
# Test Accuracy of 6: 94.8
# Test Accuracy of 7: 95.2
# Test Accuracy of 8: 93.0
# Test Accuracy of 9: 94.8
# Epoch:[36]-Iteration:[100], training loss: 0.192
# Epoch:[36]-Iteration:[200], training loss: 0.196
# Time cost of one epoch: [49]s
# Epoch:[36], training accuracy: 94.3, training loss: 0.195
# Accuracy of the network on test images: 94.04
# Test Accuracy of 0: 94.8
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 94.6
# Test Accuracy of 3: 90.6
# Test Accuracy of 4: 96.0
# Test Accuracy of 5: 93.4
# Test Accuracy of 6: 94.6
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 93.2
# Test Accuracy of 9: 94.8
# Epoch:[37]-Iteration:[100], training loss: 0.195
# Epoch:[37]-Iteration:[200], training loss: 0.193
# Time cost of one epoch: [49]s
# Epoch:[37], training accuracy: 94.4, training loss: 0.192
# Accuracy of the network on test images: 94.06
# Test Accuracy of 0: 94.8
# Test Accuracy of 1: 93.2
# Test Accuracy of 2: 94.8
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 96.0
# Test Accuracy of 5: 93.4
# Test Accuracy of 6: 94.6
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 93.2
# Test Accuracy of 9: 94.8
# Epoch:[38]-Iteration:[100], training loss: 0.198
# Epoch:[38]-Iteration:[200], training loss: 0.199
# Time cost of one epoch: [49]s
# Epoch:[38], training accuracy: 94.2, training loss: 0.196
# Accuracy of the network on test images: 94.02
# Test Accuracy of 0: 94.6
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 94.8
# Test Accuracy of 3: 90.8
# Test Accuracy of 4: 95.8
# Test Accuracy of 5: 93.4
# Test Accuracy of 6: 94.6
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 93.0
# Test Accuracy of 9: 94.8
# Epoch:[39]-Iteration:[100], training loss: 0.192
# Epoch:[39]-Iteration:[200], training loss: 0.192
# Time cost of one epoch: [50]s
# Epoch:[39], training accuracy: 94.4, training loss: 0.192
# Accuracy of the network on test images: 93.96
# Test Accuracy of 0: 94.4
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 94.6
# Test Accuracy of 3: 90.4
# Test Accuracy of 4: 95.8
# Test Accuracy of 5: 93.6
# Test Accuracy of 6: 94.6
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 93.0
# Test Accuracy of 9: 94.8
# Epoch:[40]-Iteration:[100], training loss: 0.199
# Epoch:[40]-Iteration:[200], training loss: 0.194
# Time cost of one epoch: [49]s
# Epoch:[40], training accuracy: 94.2, training loss: 0.194
# Accuracy of the network on test images: 93.96
# Test Accuracy of 0: 94.4
# Test Accuracy of 1: 93.4
# Test Accuracy of 2: 94.6
# Test Accuracy of 3: 90.6
# Test Accuracy of 4: 95.8
# Test Accuracy of 5: 93.6
# Test Accuracy of 6: 94.6
# Test Accuracy of 7: 95.0
# Test Accuracy of 8: 92.8
# Test Accuracy of 9: 94.8
# Finished Training
# time required 2295.91s

# %%
# For visualization purpose
"""
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(list(range(1,epoch+1)), history["train_accuracy"], label="Train")
plt.plot(list(range(1,epoch+1)), history["val_accuracy"], label="Test")
plt.xlabel("Epoch")
ax = plt.gca()
ax.set_ylim([90, 95])
plt.ylabel("Accuracy")
plt.legend()
plt.show()
"""
# Out:
# '\nimport matplotlib.pyplot as plt\n%matplotlib inline\n\nplt.plot(list(range(1,epoch+1)), history["train_accuracy"], label="Train")\nplt.plot(list(range(1,epoch+1)), history["val_accuracy"], label="Test")\nplt.xlabel("Epoch")\nax = plt.gca()\nax.set_ylim([90, 95])\nplt.ylabel("Accuracy")\nplt.legend()\nplt.show()\n'

# %%
print("Epoch with max test accuracy:", history["val_accuracy"].index(max(history["val_accuracy"]))+1)
# Out:
# Epoch with max test accuracy: 27
